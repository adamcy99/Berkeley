# %%
Cluster0 = """
'6560116ESEG6', '656011AZSEF3', '65601J6YSED4', '65601J6ZSEA3', '65601J95SEE1', '6A04F039SOA1', 
'6560136LSEF2', '6A04E176SOE1', '6A04F409SOF2', '6A04D176SOD6', '6A04D026SOE2', '6A04H176SOF2', 
'6A04H233SOD1', '6A04I037SOA1', '65602778SEC6', '6560278FSEA3', '6A04J161SOC3', '6A04C057SOG7', 
'6A04D133SOC4', '6A04D134SOG6', '6A04D054SOB7', '6A04D058SOE1', '6A04D194SOE2', '6A046370SOA6', 
'6560109VSEE7', '65603W7DSEE0', '6A04H077SOD0', '6A04H118SOB4', '6A04G147SOD0', '6A04G184SOA7', 
'6A04G188SOD1', '6A04G191SOA0', '6A04L129SOE3', '6A04L146SOA5', '65603S79SEF0', '65603S7GSEF4', 
'65603S8DSEE5', '65603S8LSEB6', '65603S9YSEC4', '65603SA0SEE3', '6A04B184SOG3', '6A04D243SOG1', 
'6A04D297SOB3', '65603S95SEE3', '65603S9NSEA0', '65603SAMSEC2', '6A04G132SOG6', '6A04G164SOG5', 
'6Q0JD095SOF5', '65601J4KSEB3', '6A04H152SOB3', '6A04I203SOE6', '6A04I242SOD6', '6A04J070SOD4', 
'6A04N141SOC2', '6A04P034SOE6', '6A04P040SOH0', '6A04K056SOF5', '6A04P051SOB0', '6A04P259SOD6', 
'6A04P286SOE4', '6560101VSEF6', '6560103VSEA0', '6560104TSED3', '65601050SEC3', '65601H1XSEA5', 
'65601H06SEG4', '65603W85SED6', '65603W99SED1', '6A04L213SOD0', '6A04N069SOB7', '6A04N087SOC3', 
'6A04P247SOF4', '65603X9ESEB5', '65603XA7SEA2', '65603XB4SEG6', '6560107ISEH0', '6560108WSEE5', 
'6A04F320SOG3', '6A04K017SOG5', '6A04M225SOB5', '6A04M271SOH1', '6A04L294SOG3', '6A04J015SOF1', 
'6A04J018SOD1', '6A04N264SOB0', '65603W3VSED4', '65603W7TSEF5', '65603X1ZSED2', '65603X2LSEH2', 
'6A04K152SOC4', '6A04K169SOH2', '6A04K195SOD6', '6A04D003SOE5', '6A04M082SOC7', '6A04M219SOG6', 
'6A04P131SOF7', '65502C46SEF2', '65502C4XSEC2', '6A04W235SOC4', '6A04W246SOD7', '6A04W361SOF4', 
'6A04W366SOE5', '6A04W399SOB3', '6A04X094SOF2', '6A04X106SOB7', '6A04X124SOC3', '6A04W387SOD1', 
'6A04X176SOD7', '6A04X177SOA6', '6A04X211SOG3', '6A04X144SOE0', '6A04X181SOB7', '6A04Y159SOA5', 
'6A04Y171SOF1', '6A04R112SOB7', '6A04V054SOB2', '6A04V355SOC7', '6A04V359SOF1', '6A04V362SOC0', 
'6A04X045SOB6', '6A04X166SOG6', '6A04N123SOB6', '6A04W310SOA7', '6A04R127SOF4', '6A04R130SOC3', 
'6A04V157SOF6', '6A04V168SOH1', '6A04W288SOA7', '6A04P268SOE0', '6A04P272SOF1', '6A04P274SOG2', 
'6A04Q265SOG3', '6A04Q290SOG0', '6A04V214SOD5', '6A04M095SOF3', '6A04M098SOD3', '6A04M099SOA2', 
'6A04M236SOD0', '6A04N119SOA5', '6A04V057SOG5', '6560152LSEA2', '65603X56SEB0', '65603X67SEC3', 
'65603X6BSEE7', '6A04R003SOC4', '6A04R006SOA4', '6A04R015SOA6', '6A04W258SOC1', '6A04W264SOE3', 
'6A04W212SOC7', '6A04X244SOD1', '6A04Y050SOA1', '6A04V052SOA1', '6A04V061SOA3', '6A04V067SOD6', 
'6A04V353SOB6', '6A04W169SOE3', '6A04W245SOH0', '6A04Q278SOB4', '6A04Q309SOC7', '6A04V383SOA4', 
'6A04V384SOE6', '6A04W190SOB6', '6A04W314SOD1', '6A04R175SOE6', '6A04M058SOA1', '6A04N197SOG0', 
'6Q0E9157SOF5', '6Q0ED057SOD2', '6Q0ED122SOE4', '6Q0ED327SOB7', '6A04R002SOF5', '6A04V051SOD2', 
'6A04V100SOF1', '6A04V251SOB4', '6A04V295SOH0', '6A04W204SOG7', '6A04W206SOA5', '6A04W251SOB7', 
'6A04W292SOC0', '6A04K091SOC3', '6A04K095SOE5', '6A04K126SOG0', '6A050133SOF3', '6A050156SOF0', 
'6A051022SOF2', '6A051024SOG3', '6A04Z148SOH0', '6A050123SOA7', '6A051018SOE1', '65506W3MSEB3', 
'65506W4VSEH2', '65506W4WSEE1', '65506W60SEC2', '65506W65SEB3', '65506W6BSEF0', '65506W73SEE6', 
'6A04W094SOE7', '6A04X200SOF0', '6A050160SOG1', '6A050205SOG7', '6A050090SOF6', '6A050095SOE7', 
'6A04Z180SOF6', '6A04Z220SOA0', '6A04Z238SOB5', '6A050053SOA4', '6A050060SOH0', '6A04Z262SOE3', 
'6A04Z270SOA3', '6A04Z196SOG2', '6A053134SOD3', '65502C45SEB0', '65502C4DSEF6', '65506U4SSED5', 
'65506U4TSEA4', '65506WAMSEF3', '65502B2CSEA6', '65502B52SEB0', '6560151KSEG2', '6A051364SOH0', 
'6A050261SOC1', '6A050305SOG0', '6A050307SOH1', '6A054122SOF4', '6A050229SOD3', '6A050238SOD5', 
'6A050240SOD5', '65506W6USEE5'
"""
Cluster1 = """
'65600XAYSED4', '65600XB3SEB3', '65600XBRSEA3', '656011AUSEG2', '656011BBSED6', '656011BMSEG2', 
'6A04F030SOG1', '6A04F041SOA1', '6A04D162SOE3', '6A04D017SOE0', '6A04J149SOF2', '6A04I009SOC4', 
'6A04J106SOE0', '6Q0JA296SOH0', '6560277NSEA3', '6560278WSEG2', '6560278YSEA0', '65602793SEF2', 
'6A04C061SOA5', '6A04D190SOC0', '6Q0JB330SOF5', '6A046349SOD3', '6A04I032SOB0', '6A04I046SOA3', 
'6A04I061SOC7', '6A04I067SOG2', '6A04I068SOD1', '6A046289SOA1', '6A046339SOG2', '6A046341SOG2', 
'6A04B031SOB4', '6A04H127SOB6', '6A04H147SOD3', '6A04H168SOB7', '6A04H276SOE3', '6A04H279SOC3', 
'6A04H280SOF4', '6A04H304SOA3', '6A04H306SOB4', '6A04I004SOD3', '6A04I049SOF6', '6A04I050SOB4', 
'6A04G156SOD2', '6A04L099SOH2', '6A04I218SOB0', '6A04B185SOD2', '6A04B186SOA1', '6A04D233SOB5', 
'6A04D238SOA6', '6A04D294SOD3', '6A04G133SOD5', '6A04G137SOF7', '6A04H128SOG0', '6A04H277SOB2', 
'6A04K145SOD3', '6A04P030SOC4', '65601039SEC1', '6560103ESEB4', '6560104MSED1', '6560104QSEF3', 
'6560104USEA2', '65601H03SEB1', '65601H05SEC2', '65603W9ASEA2', '6A04P073SOD6', '6A04P078SOC7', 
'65603XAESEA6', '65603XALSEB0', '65603XATSEF4', '6A04N038SOG2', '6A04R211SOE1', '6A04R233SOG7', 
'6A04R236SOE7', '6A04K039SOC0', '6A04L166SOC2', '6A04H045SOD1', '6A04N278SOA3', '6A04D008SOD6', 
'6A04D009SOA5', '6A04D302SOF1', '6A04M017SOA0', '6A04M045SOF0', '6A04M220SOC4', '6A04P164SOC5', 
'6A04P167SOA5', '6A04Q283SOG7', '6A04X119SOE3', '6A04X220SOG5', '6A04Y091SOA2', '6A04W162SOE1', 
'6A04W170SOA1', '6A04Y163SOB6', '6A04Y174SOD1', '6A04W316SOE2', '6A04X015SOD0', '6A04W193SOH1', 
'6A04R126SOB2', '6A04N196SOB6', '6A04M130SOA4', '6A04M133SOF7', '6A04V301SOA2', '6560152ISEC2', 
'65603X58SEC1', '65603X66SEF4', '6A04N096SOC5', '6A04N114SOB4', '6A04X242SOC0', '6A04W177SOA3', 
'6A04W189SOG0', '6A04V027SOA4', '6A04V170SOH1', '6A04V360SOA7', '6A04V155SOE5', '6A04V133SOB7', 
'6A04W289SOF1', '6A04I080SOA2', '6A04I083SOF5', '6A04X153SOE2', '6A050154SOD7', '6A04Z139SOG6', 
'65506W3QSED5', '65506W5SSEG3', '6A04I092SOF7', '65506W7ASEF2', '65506WA9SEB4', '6A04Z135SOE4', 
'6A04Z147SOC6', '6A050096SOB6', '6A050099SOH1', '6A04Z179SOC5', '6A050174SOF4', '6A051164SOB3', 
'65502B4NSEE7', '6560151YSEG6', '6A053043SOE4', '6A051278SOH2', '6A057206SOG3', '6A059148SOF0'
"""

Cluster2 = """
'6A047255SOG7', '6A04F308SOB7', '65601305SEF7', '6560130ESEA1', '6560138NSEA5', '6560139BSEF6', 
'6560139CSEC5', '6560139GSEE7', '656013A3SEA1', '656013A7SEC3', '656013A8SEG5', '6A04F003SOF3', 
'6A04F015SOD5', '6A04F383SOB7', '6A04D164SOF4', '6A04D165SOC3', '6A04E125SOG7', '6A04D033SOD3', 
'6A04H265SOD0', '6A04D183SOC7', '6A04G193SOB1', '6A04H107SOA1', '6A04H108SOE3', '6A04F083SOE4', 
'6A04G092SOF1', '6A04G099SOF3', '6A04G149SOE1', '6A04G150SOH2', '6A04L070SOE2', '6A04L106SOE6', 
'6Q0JE004SOF4', '6A04L138SOE5', '65603S7DSEA1', '65603S8ESEB4', '6A04B191SOF4', '6A04D068SOB2', 
'6A04E058SOE4', '6A04E059SOB3', '65603S97SEF4', '65603S9DSEB6', '65603S9ESEG0', '6A04G135SOE6', 
'6Q0JD152SOD4', '6Q0JD180SOB1', '65601J3MSEF3', '65603W8QSEE6', '6A04H156SOD5', '6A04H174SOE1', 
'6A04J071SOA3', '6A04K117SOF6', '6A04K139SOB1', '6A04K212SOF6', '6A04K213SOC5', '6A04K260SOF0', 
'6A04P031SOG6', '6A04H126SOE7', '6A04H207SOG5', '6A04P066SOE5', '6560103ASEG5', '6560104PSEB1', 
'65601H0LSEE1', '65603W86SEA5', '6A04N091SOD4', '65603W7PSED3', '6560107HSEC6', '6560107WSEA1', 
'6560107XSEE3', '6560108ESEB7', '6560108GSED0', '6560108HSEH2', '6560108JSEB0', '6560108LSEC1', 
'6560108PSEE3', '6560108RSEF4', '6560108SSEC3', '6560108YSEF6', '65601090SEF5', '656010A6SEA6', 
'6A04N062SOB5', '6A04F280SOE6', '6A04G019SOG2', '6A04G021SOG2', '6A04M260SOF6', '6A04N133SOG2', 
'6A04D109SOH1', '6A04L109SOC6', '6A04L275SOB5', '6A04P149SOA1', '6A04K101SOF2', '6A04L154SOE0', 
'6A04L171SOA2', '6A04I263SOC2', '6A04I265SOD3', '6A04J012SOH1', '6A04R279SOG1', '65603W6MSEA7', 
'65603W6PSEG2', '65603W71SEE3', '65603X7PSEC4', '6A04H010SOF2', '6A04N100SOC1', '6A04W272SOA3', 
'6A04X058SOE2', '6A04X098SOA1', '6A04X120SOA1', '6A04X210SOC1', '6A04X216SOF4', '6A04W157SOG1', 
'6A04W161SOH2', '6A04W164SOF2', '6A04W165SOC1', '6A04W171SOE3', '6A04W317SOB1', '6A04X010SOD7', 
'6A04X145SOA7', '6A04Y130SOF0', '6A04Y167SOE0', '6A04Y170SOA7', '6A04Q163SOG1', '6A04Q235SOA2', 
'6A04X009SOA6', '6A04X021SOF2', '6A04X162SOE4', '6A04W198SOG2', '6A04W301SOA5', '6A04V171SOE0', 
'6A04V272SOA0', '6A04V302SOE4', '6A04W323SOD3', '6A04M079SOG0', '6A04M097SOG4', '6A04N098SOD6', 
'6A04N101SOG3', '6A04N108SOG5', '6A04N121SOA5', '6A04V063SOB4', '6A04V255SOD6', '6A04V257SOE7', 
'6A04V347SOG7', '6A04W195SOA7', '6560152BSEC0', '65603X53SED0', '65603X6ASEA5', '65603X6ESEC7', 
'65603X6FSEH1', '6A04Q062SOC6', '6A04Q173SOD2', '6A04R009SOF7', '6A04R013SOH0', '6A04R014SOD7', 
'6A04R020SOG1', '6A04W262SOD2', '6A04W263SOA1', '6A04W213SOH1', '6A04V059SOA3', '6A04W180SOE5', 
'6A04W216SOF1', '6A04V164SOE7', '6A04V349SOA5', '6A04R010SOB5', '6A04V031SOB5', '6A04V283SOB3', 
'6A04V286SOG6', '6A04V292SOB5', '6A04V298SOF0', '6A04V304SOF5', '6A04V306SOG6', '6A04Q293SOE0', 
'6A04Q254SOF0', '6A04Q282SOC5', '6A04R056SOA7', '6A04V270SOG2', '6A04V314SOC6', '6A04V317SOA6', 
'6A04V319SOB7', '6A04V322SOG1', '6A04V366SOE2', '6A04V368SOF3', '6A04W313SOG2', '6A04N198SOC7', 
'6Q0ED086SOF1', '6A04W218SOG2', '6A04W220SOG2', '6A04W252SOG1', '6A04W279SOA5', '6A050114SOA5', 
'6A051017SOH2', '65506W6ASEA6', '6A04W090SOC5', '6A04W098SOH1', '6A050142SOF5', '6A051006SOF7', 
'65506W4SSEB7', '6A04Z103SOE5', '6A050055SOB5', '6A050094SOA5', '6A050100SOB2', '6A050057SOC6', 
'6A050168SOD2', '6A050217SOF1', '6A050056SOF7', '6A050109SOC5', '6A051157SOC2', '6A053301SOE7', 
'65502C43SEH2', '6560151WSEF5', '6A053019SOB6', '6A053113SOE7', '6A053024SOH1', '6A053329SOD5', 
'6A050309SOA7', '6A04Z117SOE0', '6A054108SOH2', '65506W6NSEE3'
"""

# %%
import pandas as pd
import numpy as np
import pyodbc
con = pyodbc.connect('DSN=DB2v11')


daysback = 300
waferIDs = Cluster2

pullParameter = """
-- sql for ELEC retrieval 
select lot_Id, wafer_Id, normalized_TestX as chipX, normalized_TestY as chipY, family_Code, lot_Grade, date, level,
    parmValue as P9_TSPC_nF_10fin_EG40_FV_Short, parmYield as yield, kerf_X, kerf_Y, radius_Center_5, quadrant, locationType
 from DMIW.ChipParmFactR chipParmFactR, 
    DMIW_Systems.TestParm testParm, 
    DMIW_Systems.Geography geography, 
    (select testedWaferKey, lot_Id, wafer_Id, family_Code, cur_Lot_Grade as lot_Grade, last_TestTimeStamp as date, level, last_Eqp_Id 
    from DMIW_Systems.TestedWafer testedWafer 
    where Last_test_date >= (current date - %d days) and Tech_id = '5H 14HP' and Level = 'FV' and Family_code = 'US' and Wafer_id in (%s) and Calcdefs = 'TXAEA' 
    group by testedWaferKey, lot_Id, wafer_Id, family_Code, cur_Lot_Grade, last_TestTimeStamp, level, last_Eqp_Id) testedWafer 
where testedWafer.testedWaferKey = chipParmFactR.testedWaferKey and 
    testParm.testParmKey = chipParmFactR.testParmKey and 
    geography.geographyKey = chipParmFactR.geographyKey and 
    chipParmFactR.parmValue is not null and abs(parmValue) < 1e25 
     and ( ucase(testParm.parm_Label) like 'P9_TSPC_NF_10FIN_EG40_FV_SHORT' )  
 order by lot_Id, wafer_Id, normalized_TestX, normalized_TestY, parm_Label, level 
 fetch first 1000000 rows only with ur 
;


""" % (daysback, waferIDs)
parameter = pd.read_sql(pullParameter,con)

parameter
# Out:
#              LOT_ID      WAFER_ID  CHIPX  CHIPY FAMILY_CODE LOT_GRADE  \
# 0     8IQP35007.000  6A04H265SOD0     17     42          US       6.9
# 1     8IQP35007.000  6A04H265SOD0     17     53          US       6.9
# 2     8IQP35007.000  6A04H265SOD0     31     64          US       6.9
# 3     8IQP35007.000  6A04H265SOD0     31     75          US       6.9
# 4     8IQP35007.000  6A04H265SOD0     45     20          US       6.9
# 5     8IQP35007.000  6A04H265SOD0     45     53          US       6.9
# 6     8IQP35007.000  6A04H265SOD0     45     75          US       6.9
# 7     8IQP35007.000  6A04H265SOD0     59      9          US       6.9
# 8     8IQP35007.000  6A04H265SOD0     59     42          US       6.9
# 9     8IQP35007.000  6A04H265SOD0     59     64          US       6.9
# 10    8IQP35007.000  6A04H265SOD0     73     20          US       6.9
# 11    8IQP35007.000  6A04H265SOD0     73     42          US       6.9
# ...

# %%
parameter.to_csv("~/Downloads/TSPC_EG40_Cluster2.csv")
