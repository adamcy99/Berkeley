# %%
import requests
import pandas as pd
import io
from smart_open import smart_open

# %%
# !pip install smart-open
# Out:
# ...
#      |████████████████████████████████| 71kB 4.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 133kB 2.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 71kB 6.5MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 5.3MB 7.0MB/s eta 0:00:01
# ...
#   Created wheel for smart-open: filename=smart_open-1.8.4-cp37-none-any.whl size=67370 sha256=f6af1b3cf5009258f28152f40c8e355aaa5f950b5932f26a7a9fc64ddddfe9dc
#   Stored in directory: /Users/acyang@us.ibm.com/Library/Caches/pip/wheels/5f/ea/fb/5b1a947b369724063b2617011f1540c44eb00e28c3d2ca8692
# Successfully built smart-open
# ...
# WARNING: You are using pip version 19.2.3, however version 19.3.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
# Limited to pulling 200 events at a time but can filter by locale
urlData = requests.get("https://app.ticketmaster.com/discovery/v2/events.json?size=200&apikey=v3sGG4CGEX0Vj22eNYfG2TAiGGAuuu4f").json()
urlData
# Out:
# {'_embedded': {'events': [{'name': 'Texas Longhorns Football vs. LSU Tigers Football',
#     'type': 'event',
#     'id': 'Z7r9jZ1Aefa4U',
#     'test': False,
#     'url': 'http://www.ticketsnow.com/InventoryBrowse/TicketList.aspx?PID=2509576',
#     'locale': 'en-us',
#     'images': [{'ratio': '3_2',
#       'url': 'https://s1.ticketm.net/dam/a/4bb/4b5d16dc-fe6f-4b44-a143-24ef118b44bb_749471_RETINA_PORTRAIT_3_2.jpg',
#       'width': 640,
#       'height': 427,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/4bb/4b5d16dc-fe6f-4b44-a143-24ef118b44bb_749471_EVENT_DETAIL_PAGE_16_9.jpg',
#       'width': 205,
#       'height': 115,
#       'fallback': False},
#      {'ratio': '16_9',
#       'url': 'https://s1.ticketm.net/dam/a/4bb/4b5d16dc-fe6f-4b44-a143-24ef118b44bb_749471_TABLET_LANDSCAPE_16_9.jpg',
#       'width': 1024,
#       'height': 576,
#       'fallback': False},
#      {'ratio': '16_9',
# ...

# %%
urlData['_embedded']['events'][99]['priceRanges']
# Out:
# [{'type': 'standard', 'currency': 'USD', 'min': 62.0, 'max': 569.5}]

# %%
event_list = []
# For each event, we access its information through its API
for event in urlData['_embedded']['events']: 
    if 'priceRanges' in event.keys():
        event_list.append([event['name'],event['locale'],event['dates'], event['sales'], event['priceRanges']])
    else:
        event_list.append([event['name'],event['locale'],event['dates'], event['sales']])
df = pd.DataFrame(event_list)

# %%
df
# Out:
#                                                     0      1  \
# 0    Texas Longhorns Football vs. LSU Tigers Football  en-us
# 1                  Oakland Raiders vs. Denver Broncos  en-us
# 2           Romeo Santos Presenta: Utopia The Concert  en-us
# 3                 Chicago Bears vs. Green Bay Packers  en-us
# 4              New Orleans Saints vs. Atlanta Falcons  en-us
# 5   Tampa Bay Buccaneers v San Francisco 49ers w/ ...  en-us
# 6             Kansas City Chiefs vs. Baltimore Ravens  en-us
# 7                  LA Clippers vs. Los Angeles Lakers  en-us
# 8   Texas Longhorns Football vs. Louisiana Tech Bu...  en-us
# 9        Los Angeles Chargers vs. Pittsburgh Steelers  en-us
# 10           Kansas City Chiefs vs. Minnesota Vikings  en-us
# 11                  New York Jets vs. New York Giants  en-us
# 12                  Dallas Cowboys vs. Miami Dolphins  en-us
# 13                 New York Jets vs. Cleveland Browns  en-us
# ...

# %%
bucket_name = 'w210topicdetection'
object_key = 'vocabulary.csv'
path = 's3://{}/{}'.format(bucket_name, object_key)
df = pd.read_csv(smart_open(path))
df.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-6-bb1dcf9ff925> in <module>()
#       2 object_key = 'vocabulary.csv'
#       3 path = 's3://{}/{}'.format(bucket_name, object_key)
# ----> 4 df = pd.read_csv(smart_open(path))
#       5 df.head()
#
# /anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py in smart_open(uri, mode, **kw)
#     451             transport_params[key] = value
#     452
# ...

# %%
aws_key = 'AKIAIND44WGHS6MVDBLQ'
aws_secret = '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'
bucket_name = 'w210topicdetection'
object_key = 'vocabulary.csv'
path = 's3://{}/{}'.format(aws_key, aws_secret, bucket_name, object_key)
df = pd.read_csv(smart_open(path))
# Out:
# /anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py:398: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# ---------------------------------------------------------------------------
# NoCredentialsError                        Traceback (most recent call last)
# <ipython-input-13-0bd3c862e998> in <module>()
#       4 object_key = 'vocabulary.csv'
#       5 path = 's3://{}/{}'.format(aws_key, aws_secret, bucket_name, object_key)
# ----> 6 df = pd.read_csv(smart_open(path))
#
# /anaconda3/lib/python3.7/site-packages/smart_open/smart_open_lib.py in smart_open(uri, mode, **kw)
#     451             transport_params[key] = value
#     452
# ...
