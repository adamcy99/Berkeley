# %%
import nltk
import numpy as np
from itertools import groupby, chain
from collections import Counter, defaultdict
import spacy
spacy_nlp = spacy.load("en_core_web_sm")
import re

class StatementExtracter(object):
    """
    As part of key word extraction and sentiment summarization, this code will be
    able to extract certain types of statements from a block of text.
    """
    
    def __init__(self, stopwords = None, punctuations = None):
        self.stopwords = stopwords
        self.punctuations = punctuations
        if self.stopwords == None:
            self.stopwords = []
        if self.punctuations == None:
            self.punctuations = list('!"#%&\'()*+,./:;<=>?@[\\]^_`{|}~♪')
        self.phrase_breaks = set(self.stopwords + self.punctuations)
        
    def replace_contraction(self, text):
        """
        Takes in text and replaces certain contractions
        """
        contraction_patterns = [(r'won\'t', 'will not'), (r'can\'t', 'can not'), (r'i\'m', 'i am'), 
                                (r'ain\'t', 'is not'), (r'(\w+)\'ll', '\g<1> will'), (r'(\w+)n\'t', '\g<1> not'),
                                (r'(\w+)\'ve', '\g<1> have'), (r'(\w+)\'d', '\g<1> would'), (r'&', 'and'),
                                (r'dammit', 'damn it'), (r'dont', 'do not'), (r'wont', 'will not'),
                                (r'they\'re', 'they are'), (r'They\'re', 'They are'), (r'it\'s', 'it is'), (r'It\'s', 'It is')]
        patterns = [(re.compile(regex), repl) for (regex, repl) in contraction_patterns]
        for (pattern, repl) in patterns:
            (text, count) = re.subn(pattern, repl, text)
        return text
        
    def spacy_POS_phrase_breaks(self, doc, POS_we_want, tag_we_want):
        """
        Inputs a string of text, a list of POS, and a list of Spacy Tags that we want to keep in.
        This method parses the text and adds words that do not fall into POS and TAGS to phrase breaks list.
        """
        # Initialize the set with our existing phrase breaks
        temp_phrase_breaks = self.phrase_breaks.copy()

        for token in doc:
            if token.pos_ not in POS_we_want and token.tag_ not in tag_we_want:
                temp_phrase_breaks.add(token.text.lower())
        return temp_phrase_breaks
    
    def visualize_POS(self,text):
        """Visualize the POS of each word in the text"""
        #text = self.replace_contraction(text)
        doc = spacy_nlp(text)
        for token in doc:
            print("{0}/{1}/{2} <--{3}-- {4}/{5}/{6}".format(
                    token.text,token.pos_,token.tag_,token.dep_,token.head.text,token.head.pos_,token.head.tag_))        
    
    def is_statements(self, text):
        # Situation where text contains sentences/punctuation
        if "2" in text:
            text = self.replace_contraction(text)
            self.statementExtraction(text, withPunctuation = True)
        # Situation where text does not contain sentences/punctuation
        else:
            text = self.replace_contraction(text)
            self.statementExtraction(text, withPunctuation = False)
        
    def statementExtraction(self, text, withPunctuation = False):
        doc = spacy_nlp(text)
        for token in doc:
            # If the token is "is" or "are", we want to look at the subtree
            #if token.text in ['is','are']:
            if token.pos_ == "VERB":
                # Pull the subtree as token objects and as pure text
                subtree = [i for i in token.subtree]

                # Split the subtree up into left and right groups
                left_subtree = [word for word in subtree if word.i < token.i]
                right_subtree = [word for word in subtree if word.i > token.i]

                if withPunctuation == True:
                    # Create a temporary set of break words based on the Part of Speech
                    left_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','PUNCT','ADP','PRON','AUX','SYM','SCONJ']
                    left_tags = []
                    right_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','ADV','PUNCT','ADP','AUX','SYM','SCONJ','CCONJ','PRON']
                    right_tags = ['VBG','VBZ','VBP','VB','VBD','VBN']
                if withPunctuation == False:
                    left_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','PRON']
                    left_tags = []
                    right_POS = ['ADJ','DET','NOUN','NUM','PART','PROPN','ADV','ADP','CCONJ']
                    right_tags = ['VB']
                left_phrase_breaks = self.spacy_POS_phrase_breaks(subtree, left_POS, left_tags)
                right_phrase_breaks = self.spacy_POS_phrase_breaks(subtree, right_POS, right_tags)

                # group words together using phrase breaks and a separator 
                left_phrase_groups = groupby(left_subtree, lambda word: word.text.lower() not in left_phrase_breaks)
                # Pull out the groups of words that do not include any of the phrase breaks   
                left_phrase_tuples = [tuple(group[1]) for group in left_phrase_groups if group[0] == True]

                # group words together using phrase breaks and a separator 
                right_phrase_groups = groupby(right_subtree, lambda word: word.text.lower() not in right_phrase_breaks)
                # Pull out the groups of words that do not include any of the phrase breaks   
                right_phrase_tuples = [tuple(group[1]) for group in right_phrase_groups if group[0] == True]

                subject = []
                description = []
                
                # For the subjects on the left side of "is/are"
                subject_word = None
                for tuple_ in left_phrase_tuples:
                    for word in tuple_:
                        # if any of the words inside the tuple is a 'nsubj', it is potentially what we want
                        if word.dep_ in ['nsubj', 'expl']:
                            # check if we already have a good candidate for subject
                            if len(subject) < 1:
                                subject_word = word
                                subject = tuple_
                                break
                            elif subject_word.pos_ in ['NOUN'] and word.pos_ not in ['NOUN']:
                                pass
                            # if the existing candidate is not a noun, then we can update it.
                            else:
                                subject_word = word
                                subject = tuple_
                                break
                #print(left_phrase_tuples, right_phrase_tuples)
                # Look at right text, if it includes adj, keep it + or just take the first phrase in the tuple.
                if len(right_phrase_tuples) > 0:
                    description = right_phrase_tuples[0]
                    
                # Create the statements
                print(subtree)
                if len(subject) > 0 and len(description) > 0:
                    output = " ".join([
                        .text for word in subject]) + " " + token.text + " " + " ".join([word.text for word in description])
                    print(output)

# %%
import pandas as pd
df = pd.read_csv("videoExamples.csv")
examples = list(df.captions)

# %%
se = StatementExtracter()

# %%
se.is_statements(examples[3])
# Out:
# [Last, year, ,, Insta360, came, out, with, the, One, X, ,, and, it, totally, revolutionized, the, idea, of, a, 360, camera, could, be, used, what, for, .]
# Insta360 came out with the One X
# [it, totally, revolutionized, the, idea, of, a, 360, camera, could, be, used, what, for, .]
# it revolutionized the idea of a 360 camera could be used what for
# [a, 360, camera, could, be, used, what, for]
# [First, off, ,, footage, shot, with, the, One, X]
# [First, off, ,, footage, shot, with, the, One, X, was, stitched, in, camera, ,, and, then, you, were, able, to, edit, it, right, on, your, phone, and, upload, to, social, platforms, almost, instantly, .]
# [to, edit, it, right, on, your, phone, and, upload, to, social, platforms, almost, instantly]
# [upload, to, social, platforms, almost, instantly]
# [Secondly, ,, they, market, it, not, as, a, 360-degree, camera, but, instead, a, camera, that, could, shoot, 360, degrees, of, possible, angles, .]
# they market it not as a 360-degree camera but instead a camera that could shoot 360 degrees of possible angles
# [that, could, shoot, 360, degrees, of, possible, angles]
# that could shoot 360 degrees of possible angles
# [fast, forward, a, year]
# [that, came, out, in, 2017]
# that came out in 2017
# [that, was, filled, with, all, of, the, headaches, of, 360, 's, past]
# [It, required, two, memory, cards, .]
# It required two memory cards
# [to, stitch, the, footage, on, a, desktop]
# [But, they, overhauled, all, of, that, with, the, Max, ,, and, they, in, turn, made, a, really, accessible, 360, camera, ,, which, makes, me, believe, I, might, continue, to, actually, use, this, thing, .]
# they overhauled all of that with the Max
# [they, in, turn, made, a, really, accessible, 360, camera, ,, which, makes, me, believe, I, might, continue, to, actually, use, this, thing, .]
# they in turn made a really accessible 360 camera
# [which, makes, me, believe, I, might, continue, to, actually, use, this, thing]
# which makes me believe I might continue to actually use this thing
# [me, believe, I, might, continue, to, actually, use, this, thing]
# me believe I might continue to actually use this thing
# [I, might, continue, to, actually, use, this, thing]
# I might continue to actually use this thing
# [to, actually, use, this, thing]
# [We, wag, ,, we, wag, ,, we, wag, ,, we, wag, ,]
# We wag we wag
# [we, wag]
# [we, wag, ,, we, wag, ,, we, wag, ,]
# we wag we wag
# [we, wag, ,]
# [we, wag]
# [GoPro, 's, made]
# [that, shoot, 16.6-megapixel]
# that shoot 16.6-megapixel
# [is, calling, Max, SuperView, photos, ,]
# [called, PowerPanos]
# [it, shows, the, same, super, satisfying, rubber, buttons, and, button, layout, as, the, Hero8, .]
# it shows the same super satisfying rubber buttons and button layout as the Hero8
# [satisfying]
# [mounting]
# [which, alas, ,, you, no, longer, need, that, housing, ,, I, somehow, always, manage, which, to, forget, anyways, ,, and, it, also, makes, it, compatible, with, all, GoPro, mounts, .]
# you need that housing
# [I, somehow, always, manage, which, to, forget, anyways]
# I manage to forget anyways
# [which, to, forget, anyways]
# [it, also, makes, it, compatible, with, all, GoPro, mounts, .]
# it makes it compatible with all GoPro mounts
# [if, you, 're, vlogging, or, taking, a, selfie]
# if you 're vlogging or taking a selfie
# [taking, a, selfie]
# [,, you, can, see, yourself, much, like, on, the, DJI, Osmo, Action, because, ,, well, ,, there, 's, lenses, on, both, sides, .]
# you can see yourself much
# [waterproof, up, to, 16, feet]
# [GoPro, claims, that, it, is, really, difficult, to, stitch, underwater, footage, ,, but, they, are, promising, some, sort, of, waterproof, housing, in, the, future, .]
# GoPro claims that it is really difficult to stitch underwater footage
# [to, stitch, underwater, footage]
# [they, are, promising, some, sort, of, waterproof, housing, in, the, future, .]
# they are promising some sort of waterproof housing in the future
# [you, can, not, scroll, around, your, frame, in, 360, mode, since, the, screen, has, swiping, gestures, such, as, swiping, down, to, reach, the, main, menu, .]
# you can not scroll around your frame in 360 mode since the screen has swiping gestures such as swiping down to reach the main menu
# [since, the, screen, has, swiping, gestures, such, as, swiping, down, to, reach, the, main, menu]
# since the screen has swiping gestures such as swiping down to reach the main menu
# [swiping, down, to, reach, the, main, menu]
# [to, reach, the, main, menu]
# [You, can, however, switch, between, lenses, but, only, while, not, recording, .]
# You can switch between lenses but only while not recording
# [only, while, not, recording]
# [Once, you, hit, that, record, button]
# Once you hit that record button
# [that, you, chose, before, rolling]
# that you chose before rolling
# [rolling]
# [The, image, on, the, screen, will, however, stay, level, with, the, horizon, no, matter, which, way, you, turn, the, camera, .]
# The image on the screen will stay level with the horizon no matter which way you turn the camera
# [which, way, you, turn, the, camera]
# which way you turn the camera
# [If, you, lean, into, that, warped, ,, super, fisheye, look]
# If you lean into that warped
# [warped]
# [that, warped, ,, super, fisheye, look]
# [If, you, lean, into, that, warped, ,, super, fisheye, look, that, only, a, 360, camera, could, give, you]
# a 360 camera could give you
# [to, overexpose, the, highlights, of, it]
# [I, prefer, this, to, the, flatter, color, grade, of, the, One, X, ,, especially, for, users, who, will, not, be, color, correcting, .]
# I prefer this to the flatter color grade of the One X
# [And, how, even, if, you, are, color, correcting, ,, I, find, that, the, Max, and, the, One, X, have, very, little, latitude, in, the, coloring, process, .]
# I find that the Max and the One X have very little latitude in the coloring process
# [coloring]
# [if, you, 're, only, gon, na, be, showing, these, photos, on, social, platforms]
# if you 're gon na be showing these photos on social platforms
# [na, be, showing, these, photos, on, social, platforms]
# [Now, ,, if, you, 're, only, gon, na, be, showing, these, photos, on, social, platforms, you, 're, gon, that, na, look, at, on, a, phone, ,, who, cares, ,, but, for, a, camera, that, costs, $, 500, ,, I, hope, it, is, going, a, little, further, than, that, .]
# these photos on social platforms you 're that gon na look at on a phone
# [that, na, look, at, on, a, phone, ,, who, cares]
# [who, cares]
# [that, costs, $, 500]
# that costs $ 500
# [for, a, camera, that, costs, $, 500, ,, I, hope, it, is, going, a, little, further, than, that, .]
# I hope it is going a little further than that
# [it, is, going, a, little, further, than, that]
# it is going a little further than that
# [The, Max, 's, 360, °, video, is, stabilized, in, software, .]
# [It, bobs, up, and, down, as, you, would, expect, from, walking, and, it, can, be, really, jittery, ,, especially, at, night, .]
# It bobs up and down as you would expect from walking and it can be really jittery
# [as, you, would, expect, from, walking]
# as you would expect from walking
# [walking]
# [once, you, export, the, 360-degree, footage]
# once you export the 360-degree footage
# [I, have, seen, on, a, camera, this, size]
# I have seen on a camera this size
# [The, wind, reduction, can, add, a, lot, of, compression, ,, and, enough, wind, can, sound, like, ,, well, this, ,, (, wind, blowing, )]
# The wind reduction can add a lot of compression
# [enough, wind, can, sound, like, ,, well, this, ,, (, wind, blowing, )]
# enough wind can sound like
# [(, wind, blowing, )]
# [when, I, say, it, is, windy, out]
# I say it is windy out
# [to, blow, over]
# [This, might, make, some, really, good, footage, as, I, fly, away, .]
# This might make some really good footage as I fly away
# [as, I, fly, away]
# as I fly away
# [But, when, you, 're, not, in, 25-mile, an, hour, wind, ,, it, actually, reduces, the, sound, of, wind, while, prioritizing, voices, .]
# it reduces the sound of wind while prioritizing voices
# [while, prioritizing, voices]
# [while, hiking, with, Alex]
# [So, while, hiking, with, Alex, ,, I, love, that, the, GoPro, picked, up, on, the, crickets, and, footsteps, ,, while, also, keeping, our, voices, at, the, forefront, no, matter, where, the, camera, was, in, space, .]
# I love that the GoPro picked up on the crickets and footsteps
# [that, the, GoPro, picked, up, on, the, crickets, and, footsteps, ,, while, also, keeping, our, voices, at, the, forefront, no, matter, where, the, camera, was, in, space]
# that the GoPro picked up on the crickets and footsteps
# [while, also, keeping, our, voices, at, the, forefront, no, matter, where, the, camera, was, in, space]
# [and, I, think, it, is, gon, na, be, a, long, ,, long, time, ♪]
# I think it is gon na be a long
# [it, is, gon, na, be, a, long, ,, long, time]
# [I, got, ta, be, honest, guys]
# I got ta be honest guys
# [not, showing, you, these, photos, before, this, video, dropped]
# [before, this, video, dropped]
# [I, mean, first, and, foremost]
# I mean first and foremost
# [I, mean, first, and, foremost, ,, they, make, taking, a, panoramic, photo, a, lot, easier, .]
# they make taking a panoramic photo a lot easier
# [taking, a, panoramic, photo, a, lot, easier]
# [to, stand, there, and, slowly, and, robotically, move, your, phone, across, the, landscape]
# [robotically, move, your, phone, across, the, landscape]
# [how, crisp, these, photos, turned, out, to]
# crisp these photos turned out to
# [Even, on, a, desktop, ,, they, still, look, really, cool, .]
# they look really cool
# [when, the, Max, just, records, the, time, lapse]
# the Max records the time lapse
# [I, saw, my, battery, drop, 15, %, off, a, fresh, charge, while, shooting, this, time, warp, .]
# I saw my battery drop 15
# [my, battery, drop, 15, %, off, a, fresh, charge, while, shooting, this, time, warp]
# my battery drop 15
# [while, shooting, this, time, warp]
# [And, I, let, it, record, for, all, of, 10, minutes, .]
# I let it record for all of 10 minutes
# [it, record, for, all, of, 10, minutes]
# it record for all of 10 minutes
# [I, think, it, would, help, if, the, screen, would, go, off, a, bit, sooner, while, shooting, these, to, save, some, battery, .]
# I think it would help if the screen would go off a bit sooner while shooting these to save some battery
# [it, would, help, if, the, screen, would, go, off, a, bit, sooner, while, shooting, these, to, save, some, battery]
# it would help if the screen would go off a bit sooner while shooting these to save some battery
# [if, the, screen, would, go, off, a, bit, sooner, while, shooting, these, to, save, some, battery]
# if the screen would go off a bit sooner while shooting these to save some battery
# [while, shooting, these, to, save, some, battery]
# [to, save, some, battery]
# [So, yes, ,, you, will, need, to, buy, extra, spares, if, you, plan, on, heavy, use, .]
# you will need to buy extra spares if you plan on heavy use
# [to, buy, extra, spares, if, you, plan, on, heavy, use]
# [if, you, plan, on, heavy, use]
# if you plan on heavy use
# [using, two, of, these, batteries]
# [GoPro, 's, app, makes, it, really, easy, to, edit, this, footage, .]
# GoPro 's app makes it really easy to edit this footage
# [to, edit, this, footage]
# [Max, uses, the, same, GoPro, app, as, the, Heroes, .]
# Max uses the same GoPro app as the Heroes
# [I, think, even, a, casual, non, -, video, director, from, the, verge.com, could, edit, the, Max, 's, 360, footage, .]
# I think even a casual non - video director from the verge.com could edit the Max 's 360 footage
# [even, a, casual, non, -, video, director, from, the, verge.com, could, edit, the, Max, 's, 360, footage]
# a casual non - video director from the verge.com could edit the Max 's 360 footage
# [And, I, actually, enjoyed, editing, it, on, the, app, .]
# I enjoyed editing it on the app
# [editing, it, on, the, app]
# [called, GoPro, Player, ,, which, mirrors, the, mobile, app, experience, with, added, codec, options, at, export]
# [which, mirrors, the, mobile, app, experience, with, added, codec, options, at, export]
# which mirrors the mobile app experience with added codec options at export
# [added]
# [as, 360, editing, goes]
# [as, far, as, 360, editing, goes, ,, I, was, blown, away, by, its, ease, .]
# 360 editing blown away by its ease
# [called, Hero, mode]
# [just, when, the, camera, 's, using, one, lens, as, opposed, to, two]
# the camera 's using one lens as opposed to two
# [as, opposed, to, two]
# [it, even, boasts, GoPro, 's, most, stable, video, called, Max, HyperSmooth, .]
# it boasts GoPro 's most stable video called Max HyperSmooth
# [called, Max, HyperSmooth]
# [called, Max, SuperView]
# [But, I, got, ta, be, honest, ,, while, it, does, sound, good, and, the, footage, is, stable, ,, the, fact, that, it, maxes, out, at, 1440p60, is, noticeable, .]
# I got ta be honest
# [while, it, does, sound, good, and, the, footage, is, stable, ,, the, fact, that, it, maxes, out, at, 1440p60, is, noticeable, .]
# while it does sound good and the footage is stable
# [that, it, maxes, out, at, 1440p60]
# that it maxes out at 1440p60
# [how, much, smoothing, is, being, done, when, the, subject, is, close, to, the, camera]
# [I, also, noticed, the, camera, struggled, to, keep, the, footage, level, with, the, horizon, ,, choosing, to, instead, focus, on, keeping, the, footage, stable, .]
# I noticed the camera struggled to keep the footage level with the horizon
# [the, camera, struggled, to, keep, the, footage, level, with, the, horizon, ,, choosing, to, instead, focus, on, keeping, the, footage, stable]
# the camera struggled to keep the footage level with the horizon
# [to, keep, the, footage, level, with, the, horizon, ,, choosing, to, instead, focus, on, keeping, the, footage, stable]
# [choosing, to, instead, focus, on, keeping, the, footage, stable]
# [to, instead, focus, on, keeping, the, footage, stable]
# [keeping, the, footage, stable]
# [when, climbing, down, this, trail, ,, which, to, be, fair]
# [So, when, climbing, down, this, trail, ,, which, to, be, fair, ,, is, a, slanted, surface, ,, the, horizon, kept, tilting, further, and, further, from, level, to, almost, a, dizzying, point, .]
# the horizon kept tilting further and further from level to almost a dizzying point
# [tilting, further, and, further, from, level, to, almost, a, dizzying, point]
# [GoPro, has, become, a, household, name, .]
# GoPro has become a household name
# [I, mean]
# [I, mean, they, are, specced, out, ,, durable, ,, tiny, ,, portable, beasts, of, cameras, .]
# I specced out
# [But, for, me, ,, it, came, down, to, the, ease, of, use, of, the, app, that, made, me, wanna, keep, using, this, thing, .]
# it came down to the ease of use of the app that made me wanna keep using this thing
# [that, made, me, wanna, keep, using, this, thing]
# that made me wanna keep using this thing
# [me, wanna, keep, using, this, thing]
# me wanna keep using this thing
# [using, this, thing]
# [used, to, mean, high, -, end, equipment, and, tons, of, headaches, and, post, ,, and, that, always, pushed, me, away, from, using, it]
# [to, mean, high, -, end, equipment, and, tons, of, headaches, and, post]
# [that, always, pushed, me, away, from, using, it]
# that pushed me away from using it
# [using, it]
# [when, you, put, all, of, that, into, the, form, factor, of, a, GoPro, ,, a, workflow, I, have, been, using, for, years]
# you put all of that into the form factor of a GoPro
# [I, have, been, using, for, years]
# I have been using for years
# [to, make, this, thing, more, than, a, novelty, camera, that, will, ultimately, end, up, in, my, forgotten, type, bed, in, my, basement]
# [that, will, ultimately, end, up, in, my, forgotten, type, bed, in, my, basement]
# that will end up in my forgotten type bed in my basement
# [Time, will, truly, tell, .]
# [I, have, used, today]
# I have used today
# [to, see, this, thing, as, specced, out]
# [this, thing, as, specced, out]
# this thing as specced out
# [(, coughing, ), 4, K, Hero, mode, ?]
# [pre]
# [pre, -]
# [All, right, ,, so, for, 499, ,, you, can, pre, -, order, a, Max, today, .]
# you can order a Max today
# [They, start, shipping, on, October, 24th, and, will, be, on, shelves, October, 27th, .]
# They start shipping on October 24th and will be on shelves October 27th
# [shipping, on, October, 24th]
# [The, 360, space, is, getting, kinda, nuts, and, the, One, X, versus, the, Max, deserves, its, whole, own, videos, ,, so, I, guess, I, will, see, you, guys, next, time, .]
# The 360 space is getting kinda nuts and the One X versus the Max deserves its whole own videos
# [the, One, X, versus, the, Max, deserves, its, whole, own, videos]
# the One X versus the Max deserves its whole own videos
# [I, guess, I, will, see, you, guys, next, time, .]
# I guess I will see you guys next time
# [I, will, see, you, guys, next, time]
# I will see you guys next time

# %%
se.visualize_POS(examples[3])
# Out:
#  /SPACE/_SP <---- (/PUNCT/-LRB-
# (/PUNCT/-LRB- <--punct-- music/NOUN/NN
# mellow/ADJ/JJ <--amod-- music/NOUN/NN
# piano/NOUN/NN <--compound-- music/NOUN/NN
# music/NOUN/NN <--ROOT-- music/NOUN/NN
# )/PUNCT/-RRB- <--punct-- music/NOUN/NN
# (/PUNCT/-LRB- <--punct-- music/NOUN/NN
# upbeat/ADJ/JJ <--amod-- music/NOUN/NN
# music/NOUN/NN <--appos-- music/NOUN/NN
# )/PUNCT/-RRB- <--punct-- music/NOUN/NN
# -/PUNCT/. <--punct-- is/AUX/VBZ
# This/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# the/DET/DT <--det-- MAX/PROPN/NNP
# GoPro/PROPN/NNP <--compound-- MAX/PROPN/NNP
# MAX/PROPN/NNP <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# And/CCONJ/CC <--cc-- 's/AUX/VBZ
# it/PRON/PRP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# GoPro/PROPN/NNP <--poss-- attempt/NOUN/NN
# 's/PART/POS <--case-- GoPro/PROPN/NNP
# second/ADJ/JJ <--amod-- attempt/NOUN/NN
# attempt/NOUN/NN <--attr-- 's/AUX/VBZ
# at/ADP/IN <--prep-- attempt/NOUN/NN
# a/DET/DT <--det-- level/NOUN/NN
# consumer/NOUN/NN <--compound-- level/NOUN/NN
# level/NOUN/NN <--pobj-- at/ADP/IN
# ,/PUNCT/, <--punct-- attempt/NOUN/NN
# 360/NUM/CD <--nummod-- camera/NOUN/NN
# camera/NOUN/NN <--appos-- attempt/NOUN/NN
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# (/PUNCT/-LRB- <--punct-- whirring/NOUN/NN
# camera/NOUN/NN <--nsubj-- whirring/NOUN/NN
# whirring/NOUN/NN <--ROOT-- whirring/NOUN/NN
# )/PUNCT/-RRB- <--punct-- whirring/NOUN/NN
# Last/ADJ/JJ <--amod-- year/NOUN/NN
# year/NOUN/NN <--npadvmod-- came/VERB/VBD
# ,/PUNCT/, <--punct-- came/VERB/VBD
# Insta360/PROPN/NNP <--nsubj-- came/VERB/VBD
# came/VERB/VBD <--ROOT-- came/VERB/VBD
# out/ADP/RP <--prt-- came/VERB/VBD
# with/ADP/IN <--prep-- came/VERB/VBD
# the/DET/DT <--det-- X/NOUN/NN
# One/NUM/CD <--nummod-- X/NOUN/NN
# X/NOUN/NN <--pobj-- with/ADP/IN
# ,/PUNCT/, <--punct-- came/VERB/VBD
# and/CCONJ/CC <--cc-- came/VERB/VBD
# it/PRON/PRP <--nsubj-- revolutionized/VERB/VBD
# totally/ADV/RB <--advmod-- revolutionized/VERB/VBD
# revolutionized/VERB/VBD <--conj-- came/VERB/VBD
# the/DET/DT <--det-- idea/NOUN/NN
# idea/NOUN/NN <--dobj-- revolutionized/VERB/VBD
# of/ADP/IN <--prep-- idea/NOUN/NN
# what/PRON/WP <--pobj-- for/ADP/IN
# a/DET/DT <--det-- camera/NOUN/NN
# 360/NUM/CD <--nummod-- camera/NOUN/NN
# camera/NOUN/NN <--nsubjpass-- used/VERB/VBN
# could/AUX/MD <--aux-- used/VERB/VBN
# be/AUX/VB <--auxpass-- used/VERB/VBN
# used/VERB/VBN <--pcomp-- of/ADP/IN
# for/ADP/IN <--prep-- used/VERB/VBN
# ./PUNCT/. <--punct-- revolutionized/VERB/VBD
# First/ADV/RB <--advmod-- off/ADV/RB
# off/ADV/RB <--advmod-- shot/VERB/VBD
# ,/PUNCT/, <--punct-- shot/VERB/VBD
# footage/NOUN/NN <--compound-- shot/VERB/VBD
# shot/VERB/VBD <--nsubjpass-- stitched/VERB/VBN
# with/ADP/IN <--prep-- shot/VERB/VBD
# the/DET/DT <--det-- X/NOUN/NN
# One/NUM/CD <--nummod-- X/NOUN/NN
# X/NOUN/NN <--pobj-- with/ADP/IN
# was/AUX/VBD <--auxpass-- stitched/VERB/VBN
# stitched/VERB/VBN <--ROOT-- stitched/VERB/VBN
# in/ADP/IN <--prep-- stitched/VERB/VBN
# camera/NOUN/NN <--pobj-- in/ADP/IN
# ,/PUNCT/, <--punct-- stitched/VERB/VBN
# and/CCONJ/CC <--cc-- stitched/VERB/VBN
# then/ADV/RB <--advmod-- were/AUX/VBD
# you/PRON/PRP <--nsubj-- were/AUX/VBD
# were/AUX/VBD <--conj-- stitched/VERB/VBN
# able/ADJ/JJ <--acomp-- were/AUX/VBD
# to/PART/TO <--aux-- edit/VERB/VB
# edit/VERB/VB <--xcomp-- able/ADJ/JJ
# it/PRON/PRP <--dobj-- edit/VERB/VB
# right/ADV/RB <--advmod-- on/ADP/IN
# on/ADP/IN <--prep-- edit/VERB/VB
# your/PRON/PRP$ <--poss-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- edit/VERB/VB
# upload/VERB/VB <--conj-- edit/VERB/VB
# to/ADP/IN <--prep-- upload/VERB/VB
# social/ADJ/JJ <--amod-- platforms/NOUN/NNS
# platforms/NOUN/NNS <--pobj-- to/ADP/IN
# almost/ADV/RB <--advmod-- instantly/ADV/RB
# instantly/ADV/RB <--advmod-- upload/VERB/VB
# ./PUNCT/. <--punct-- were/AUX/VBD
# Secondly/ADV/RB <--advmod-- market/VERB/VBP
# ,/PUNCT/, <--punct-- market/VERB/VBP
# they/PRON/PRP <--nsubj-- market/VERB/VBP
# market/VERB/VBP <--ROOT-- market/VERB/VBP
# it/PRON/PRP <--dobj-- market/VERB/VBP
# not/PART/RB <--neg-- as/SCONJ/IN
# as/SCONJ/IN <--prep-- market/VERB/VBP
# a/DET/DT <--det-- camera/NOUN/NN
# 360-degree/NUM/CD <--nummod-- camera/NOUN/NN
# camera/NOUN/NN <--pobj-- as/SCONJ/IN
# but/CCONJ/CC <--cc-- camera/NOUN/NN
# instead/ADV/RB <--advmod-- camera/NOUN/NN
# a/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--conj-- camera/NOUN/NN
# that/PRON/WDT <--nsubj-- shoot/VERB/VB
# could/AUX/MD <--aux-- shoot/VERB/VB
# shoot/VERB/VB <--relcl-- camera/NOUN/NN
# 360/NUM/CD <--nummod-- degrees/NOUN/NNS
# degrees/NOUN/NNS <--dobj-- shoot/VERB/VB
# of/ADP/IN <--prep-- degrees/NOUN/NNS
# possible/ADJ/JJ <--amod-- angles/NOUN/NNS
# angles/NOUN/NNS <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- market/VERB/VBP
# Now/ADV/RB <--advmod-- have/AUX/VBP
# fast/VERB/VB <--advmod-- have/AUX/VBP
# forward/ADV/RB <--advmod-- fast/VERB/VB
# a/DET/DT <--det-- year/NOUN/NN
# year/NOUN/NN <--npadvmod-- fast/VERB/VB
# and/CCONJ/CC <--cc-- have/AUX/VBP
# we/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# the/DET/DT <--det-- Max/PROPN/NNP
# GoPro/PROPN/NNP <--compound-- Max/PROPN/NNP
# Max/PROPN/NNP <--dobj-- have/AUX/VBP
# ,/PUNCT/, <--punct-- Max/PROPN/NNP
# which/PRON/WDT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- Max/PROPN/NNP
# the/DET/DT <--det-- successor/NOUN/NN
# successor/NOUN/NN <--attr-- is/AUX/VBZ
# to/ADP/IN <--prep-- successor/NOUN/NN
# the/DET/DT <--det-- Fusion/PROPN/NNP
# GoPro/PROPN/NNP <--compound-- Fusion/PROPN/NNP
# Fusion/PROPN/NNP <--pobj-- to/ADP/IN
# that/PRON/WDT <--nsubj-- came/VERB/VBD
# came/VERB/VBD <--relcl-- successor/NOUN/NN
# out/ADP/RP <--prt-- came/VERB/VBD
# in/ADP/IN <--prep-- came/VERB/VBD
# 2017/NUM/CD <--pobj-- in/ADP/IN
# ,/PUNCT/, <--punct-- Max/PROPN/NNP
# that/PRON/WDT <--nsubjpass-- filled/VERB/VBN
# was/AUX/VBD <--auxpass-- filled/VERB/VBN
# filled/VERB/VBN <--relcl-- Max/PROPN/NNP
# with/ADP/IN <--prep-- filled/VERB/VBN
# all/DET/DT <--pobj-- with/ADP/IN
# of/ADP/IN <--prep-- all/DET/DT
# the/DET/DT <--det-- headaches/NOUN/NNS
# headaches/NOUN/NNS <--pobj-- of/ADP/IN
# of/ADP/IN <--prep-- headaches/NOUN/NNS
# 360/NUM/CD <--poss-- past/NOUN/NN
# 's/PART/POS <--case-- 360/NUM/CD
# past/NOUN/NN <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- have/AUX/VBP
# It/PRON/PRP <--nsubj-- required/VERB/VBD
# required/VERB/VBD <--ROOT-- required/VERB/VBD
# two/NUM/CD <--nummod-- cards/NOUN/NNS
# memory/NOUN/NN <--compound-- cards/NOUN/NNS
# cards/NOUN/NNS <--dobj-- required/VERB/VBD
# ./PUNCT/. <--punct-- required/VERB/VBD
# You/PRON/PRP <--nsubj-- had/AUX/VBD
# had/AUX/VBD <--ROOT-- had/AUX/VBD
# to/PART/TO <--aux-- stitch/VERB/VB
# stitch/VERB/VB <--xcomp-- had/AUX/VBD
# the/DET/DT <--det-- footage/NOUN/NN
# footage/NOUN/NN <--dobj-- stitch/VERB/VB
# on/ADP/IN <--prep-- stitch/VERB/VB
# a/DET/DT <--det-- desktop/NOUN/NN
# desktop/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- had/AUX/VBD
# But/CCONJ/CC <--cc-- overhauled/VERB/VBD
# they/PRON/PRP <--nsubj-- overhauled/VERB/VBD
# overhauled/VERB/VBD <--ROOT-- overhauled/VERB/VBD
# all/DET/DT <--dobj-- overhauled/VERB/VBD
# of/ADP/IN <--prep-- all/DET/DT
# that/DET/DT <--pobj-- of/ADP/IN
# with/ADP/IN <--prep-- overhauled/VERB/VBD
# the/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--pobj-- with/ADP/IN
# ,/PUNCT/, <--punct-- overhauled/VERB/VBD
# and/CCONJ/CC <--cc-- overhauled/VERB/VBD
# they/PRON/PRP <--nsubj-- made/VERB/VBD
# in/ADP/IN <--prep-- made/VERB/VBD
# turn/NOUN/NN <--pobj-- in/ADP/IN
# made/VERB/VBD <--conj-- overhauled/VERB/VBD
# a/DET/DT <--det-- camera/NOUN/NN
# really/ADV/RB <--advmod-- accessible/ADJ/JJ
# accessible/ADJ/JJ <--amod-- camera/NOUN/NN
# 360/NUM/CD <--nummod-- camera/NOUN/NN
# camera/NOUN/NN <--dobj-- made/VERB/VBD
# ,/PUNCT/, <--punct-- camera/NOUN/NN
# which/PRON/WDT <--nsubj-- makes/VERB/VBZ
# makes/VERB/VBZ <--relcl-- camera/NOUN/NN
# me/PRON/PRP <--nsubj-- believe/VERB/VB
# believe/VERB/VB <--ccomp-- makes/VERB/VBZ
# I/PRON/PRP <--nsubj-- continue/VERB/VB
# might/AUX/MD <--aux-- continue/VERB/VB
# continue/VERB/VB <--ccomp-- believe/VERB/VB
# to/PART/TO <--aux-- use/VERB/VB
# actually/ADV/RB <--advmod-- use/VERB/VB
# use/VERB/VB <--xcomp-- continue/VERB/VB
# this/DET/DT <--det-- thing/NOUN/NN
# thing/NOUN/NN <--dobj-- use/VERB/VB
# ./PUNCT/. <--punct-- made/VERB/VBD
# ♪/PROPN/NNP <--ROOT-- ♪/PROPN/NNP
# We/PRON/PRP <--nsubj-- wag/VERB/VBP
# wag/VERB/VBP <--ROOT-- wag/VERB/VBP
# ,/PUNCT/, <--punct-- wag/VERB/VBP
# we/PRON/PRP <--nsubj-- wag/VERB/VBP
# wag/VERB/VBP <--ccomp-- wag/VERB/VBP
# ,/PUNCT/, <--punct-- wag/VERB/VBP
# we/PRON/PRP <--nsubj-- wag/VERB/VBP
# wag/VERB/VBP <--pcomp-- ,/PUNCT/,
# ,/PUNCT/, <--punct-- wag/VERB/VBP
# we/PRON/PRP <--nsubj-- wag/VERB/VBP
# wag/VERB/VBP <--conj-- wag/VERB/VBP
# ,/PUNCT/, <--punct-- wag/VERB/VBP
# we/PRON/PRP <--nsubj-- wag/VERB/VBD
# wag/VERB/VBD <--ROOT-- wag/VERB/VBD
# ♪/PROPN/NNP <--ROOT-- ♪/PROPN/NNP
# ♪/PROPN/NNP <--ROOT-- ♪/PROPN/NNP
# This/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# the/DET/DT <--det-- angle/NOUN/NN
# widest/ADJ/JJS <--amod-- angle/NOUN/NN
# angle/NOUN/NN <--attr-- is/AUX/VBZ
# GoPro/PROPN/NNP <--nsubj-- made/VERB/VBD
# 's/PART/POS <--case-- GoPro/PROPN/NNP
# made/VERB/VBD <--relcl-- angle/NOUN/NN
# ♪/ADJ/JJ <--punct-- is/AUX/VBZ
# ♪/PROPN/NNP <--ROOT-- ♪/PROPN/NNP
# This/DET/DT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# the/DET/DT <--det-- wide/ADJ/JJ
# wide/ADJ/JJ <--attr-- is/AUX/VBZ
# ♪/NOUN/NN <--punct-- is/AUX/VBZ
# The/DET/DT <--det-- MAX/PROPN/NNP
# GoPro/PROPN/NNP <--compound-- MAX/PROPN/NNP
# MAX/PROPN/NNP <--nsubj-- has/AUX/VBZ
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# dual/ADJ/JJ <--amod-- lenses/NOUN/NNS
# 180-degree/NUM/CD <--nummod-- lenses/NOUN/NNS
# lenses/NOUN/NNS <--dobj-- has/AUX/VBZ
# that/PRON/WDT <--nsubj-- shoot/VERB/VBP
# shoot/VERB/VBP <--relcl-- lenses/NOUN/NNS
# 16.6-megapixel/PROPN/NNP <--dobj-- shoot/VERB/VBP
# ,/PUNCT/, <--punct-- lenses/NOUN/NNS
# 360-degree/NUM/CD <--nummod-- photos/NOUN/NNS
# photos/NOUN/NNS <--appos-- lenses/NOUN/NNS
# ,/PUNCT/, <--punct-- photos/NOUN/NNS
# 5.5-megapixel/NUM/CD <--nummod-- lens/NOUN/NN
# single/ADJ/JJ <--amod-- lens/NOUN/NN
# lens/NOUN/NN <--conj-- photos/NOUN/NNS
# ,/PUNCT/, <--punct-- lens/NOUN/NN
# or/CCONJ/CC <--cc-- lens/NOUN/NN
# GoPro/PROPN/NNP <--conj-- lens/NOUN/NN
# is/AUX/VBZ <--aux-- calling/VERB/VBG
# calling/VERB/VBG <--ccomp-- has/AUX/VBZ
# Max/PROPN/NNP <--compound-- SuperView/PROPN/NNP
# SuperView/PROPN/NNP <--compound-- photos/NOUN/NNS
# photos/NOUN/NNS <--dobj-- calling/VERB/VBG
# ,/PUNCT/, <--punct-- calling/VERB/VBG
# and/CCONJ/CC <--cc-- has/AUX/VBZ
# the/DET/DT <--det-- photos/NOUN/NNS
# super/ADV/RB <--advmod-- cool/ADJ/JJ
# cool/ADJ/JJ <--amod-- photos/NOUN/NNS
# 6.2-megapixel/NUM/CD <--nummod-- photos/NOUN/NNS
# panoramic/ADJ/JJ <--amod-- photos/NOUN/NNS
# photos/NOUN/NNS <--conj-- has/AUX/VBZ
# called/VERB/VBN <--acl-- photos/NOUN/NNS
# PowerPanos/PROPN/NNP <--oprd-- called/VERB/VBN
# ./PUNCT/. <--punct-- photos/NOUN/NNS
# Video/NOUN/NN <--npadvmod-- wise/ADV/RB
# -/PUNCT/HYPH <--punct-- wise/ADV/RB
# wise/ADV/RB <--advcl-- have/AUX/VBP
# ,/PUNCT/, <--punct-- have/AUX/VBP
# you/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# 1440p60/ADJ/JJ <--amod-- video/NOUN/NN
# video/NOUN/NN <--dobj-- have/AUX/VBP
# with/ADP/IN <--prep-- video/NOUN/NN
# a/DET/DT <--det-- lens/NOUN/NN
# single/ADJ/JJ <--amod-- lens/NOUN/NN
# lens/NOUN/NN <--pobj-- with/ADP/IN
# and/CCONJ/CC <--cc-- lens/NOUN/NN
# 5.6K30/NUM/CD <--nummod-- video/NOUN/NN
# spherical/ADJ/JJ <--amod-- video/NOUN/NN
# video/NOUN/NN <--conj-- lens/NOUN/NN
# ,/PUNCT/, <--punct-- have/AUX/VBP
# just/ADV/RB <--advmod-- like/SCONJ/IN
# like/SCONJ/IN <--prep-- have/AUX/VBP
# the/DET/DT <--det-- Insta360/PROPN/NNP
# Insta360/PROPN/NNP <--pobj-- like/SCONJ/IN
# ./PUNCT/. <--punct-- have/AUX/VBP
# There/PRON/EX <--expl-- are/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# mics/NOUN/NNS <--attr-- are/AUX/VBP
# on/ADP/IN <--prep-- mics/NOUN/NNS
# all/DET/DT <--det-- side/NOUN/NN
# but/CCONJ/CC <--cc-- one/NUM/CD
# one/NUM/CD <--nummod-- side/NOUN/NN
# side/NOUN/NN <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- are/AUX/VBP
# it/PRON/PRP <--nsubj-- shows/VERB/VBZ
# shows/VERB/VBZ <--conj-- are/AUX/VBP
# the/DET/DT <--det-- buttons/NOUN/NNS
# same/ADJ/JJ <--amod-- buttons/NOUN/NNS
# super/ADJ/JJ <--amod-- buttons/NOUN/NNS
# satisfying/VERB/VBG <--amod-- buttons/NOUN/NNS
# rubber/NOUN/NN <--compound-- buttons/NOUN/NNS
# buttons/NOUN/NNS <--dobj-- shows/VERB/VBZ
# and/CCONJ/CC <--cc-- buttons/NOUN/NNS
# button/NOUN/NN <--compound-- layout/NOUN/NN
# layout/NOUN/NN <--conj-- buttons/NOUN/NNS
# as/SCONJ/IN <--prep-- buttons/NOUN/NNS
# the/DET/DT <--det-- Hero8/PROPN/NNP
# Hero8/PROPN/NNP <--pobj-- as/SCONJ/IN
# ./PUNCT/. <--punct-- shows/VERB/VBZ
# On/ADP/IN <--prep-- have/AUX/VBP
# the/DET/DT <--det-- bottom/NOUN/NN
# bottom/NOUN/NN <--pobj-- On/ADP/IN
# ,/PUNCT/, <--punct-- have/AUX/VBP
# you/PRON/PRP <--nsubj-- have/AUX/VBP
# have/AUX/VBP <--ROOT-- have/AUX/VBP
# these/DET/DT <--det-- prongs/NOUN/NNS
# new/ADJ/JJ <--amod-- prongs/NOUN/NNS
# stowable/ADJ/JJ <--amod-- prongs/NOUN/NNS
# mounting/VERB/VBG <--amod-- prongs/NOUN/NNS
# prongs/NOUN/NNS <--dobj-- have/AUX/VBP
# ,/PUNCT/, <--punct-- prongs/NOUN/NNS
# which/PRON/WDT <--nsubj-- alas/INTJ/UH
# alas/INTJ/UH <--advmod-- need/VERB/VBP
# ,/PUNCT/, <--punct-- need/VERB/VBP
# you/PRON/PRP <--nsubj-- need/VERB/VBP
# no/ADV/RB <--neg-- longer/ADV/RB
# longer/ADV/RB <--advmod-- need/VERB/VBP
# need/VERB/VBP <--relcl-- prongs/NOUN/NNS
# that/DET/DT <--det-- housing/NOUN/NN
# housing/NOUN/NN <--dobj-- need/VERB/VBP
# ,/PUNCT/, <--punct-- housing/NOUN/NN
# which/PRON/WDT <--dobj-- forget/VERB/VB
# I/PRON/PRP <--nsubj-- manage/VERB/VBP
# somehow/ADV/RB <--advmod-- manage/VERB/VBP
# always/ADV/RB <--advmod-- manage/VERB/VBP
# manage/VERB/VBP <--relcl-- housing/NOUN/NN
# to/PART/TO <--aux-- forget/VERB/VB
# forget/VERB/VB <--xcomp-- manage/VERB/VBP
# anyways/ADV/RB <--advmod-- forget/VERB/VB
# ,/PUNCT/, <--punct-- need/VERB/VBP
# and/CCONJ/CC <--cc-- need/VERB/VBP
# it/PRON/PRP <--nsubj-- makes/VERB/VBZ
# also/ADV/RB <--advmod-- makes/VERB/VBZ
# makes/VERB/VBZ <--conj-- need/VERB/VBP
# it/PRON/PRP <--nsubj-- compatible/ADJ/JJ
# compatible/ADJ/JJ <--ccomp-- makes/VERB/VBZ
# with/ADP/IN <--prep-- compatible/ADJ/JJ
# all/DET/DT <--det-- mounts/NOUN/NNS
# GoPro/PROPN/NNP <--compound-- mounts/NOUN/NNS
# mounts/NOUN/NNS <--pobj-- with/ADP/IN
# ./PUNCT/. <--punct-- makes/VERB/VBZ
# The/DET/DT <--det-- touchscreen/NOUN/NN
# touchscreen/NOUN/NN <--nsubj-- is/AUX/VBZ
# on/ADP/IN <--prep-- touchscreen/NOUN/NN
# the/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--pobj-- on/ADP/IN
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- bit/NOUN/NN
# bit/NOUN/NN <--npadvmod-- smaller/ADJ/JJR
# smaller/ADJ/JJR <--acomp-- is/AUX/VBZ
# than/SCONJ/IN <--prep-- smaller/ADJ/JJR
# the/DET/DT <--det-- touchscreen/NOUN/NN
# touchscreen/NOUN/NN <--pobj-- than/SCONJ/IN
# on/ADP/IN <--prep-- is/AUX/VBZ
# the/DET/DT <--det-- back/NOUN/NN
# back/NOUN/NN <--pobj-- on/ADP/IN
# of/ADP/IN <--prep-- back/NOUN/NN
# the/DET/DT <--det-- Hero/PROPN/NNP
# Hero/PROPN/NNP <--pobj-- of/ADP/IN
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- is/AUX/VBZ
# its/PRON/PRP$ <--poss-- system/NOUN/NN
# menu/NOUN/NN <--compound-- system/NOUN/NN
# system/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--conj-- is/AUX/VBZ
# identical/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# The/DET/DT <--det-- plus/CCONJ/CC
# big/ADJ/JJ <--amod-- plus/CCONJ/CC
# plus/CCONJ/CC <--nsubj-- is/AUX/VBZ
# here/ADV/RB <--advmod-- plus/CCONJ/CC
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# if/SCONJ/IN <--mark-- vlogging/VERB/VBG
# you/PRON/PRP <--nsubj-- vlogging/VERB/VBG
# 're/AUX/VBP <--aux-- vlogging/VERB/VBG
# vlogging/VERB/VBG <--ccomp-- is/AUX/VBZ
# or/CCONJ/CC <--cc-- vlogging/VERB/VBG
# taking/VERB/VBG <--conj-- vlogging/VERB/VBG
# a/DET/DT <--det-- selfie/NOUN/NN
# selfie/NOUN/NN <--dobj-- taking/VERB/VBG
# ,/PUNCT/, <--punct-- see/VERB/VB
# you/PRON/PRP <--nsubj-- see/VERB/VB
# can/AUX/MD <--aux-- see/VERB/VB
# see/VERB/VB <--ROOT-- see/VERB/VB
# yourself/PRON/PRP <--dobj-- see/VERB/VB
# much/ADV/RB <--advmod-- like/INTJ/UH
# like/INTJ/UH <--prep-- see/VERB/VB
# on/ADP/IN <--prep-- like/INTJ/UH
# the/DET/DT <--det-- Action/PROPN/NNP
# DJI/PROPN/NNP <--compound-- Action/PROPN/NNP
# Osmo/PROPN/NNP <--compound-- Action/PROPN/NNP
# Action/PROPN/NNP <--pobj-- on/ADP/IN
# because/SCONJ/IN <--mark-- 's/AUX/VBZ
# ,/PUNCT/, <--punct-- 's/AUX/VBZ
# well/INTJ/UH <--intj-- 's/AUX/VBZ
# ,/PUNCT/, <--punct-- 's/AUX/VBZ
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--advcl-- see/VERB/VB
# lenses/NOUN/NNS <--attr-- 's/AUX/VBZ
# on/ADP/IN <--prep-- lenses/NOUN/NNS
# both/DET/DT <--det-- sides/NOUN/NNS
# sides/NOUN/NNS <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- see/VERB/VB
# The/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# waterproof/VERB/VBN <--acomp-- is/AUX/VBZ
# up/ADV/RB <--quantmod-- 16/NUM/CD
# to/PART/TO <--quantmod-- 16/NUM/CD
# 16/NUM/CD <--nummod-- feet/NOUN/NNS
# feet/NOUN/NNS <--dobj-- waterproof/VERB/VBN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# But/CCONJ/CC <--cc-- is/AUX/VBZ
# that/DET/DT <--det-- proofing/NOUN/NN
# proofing/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# merely/ADV/RB <--advmod-- is/AUX/VBZ
# for/ADP/IN <--prep-- is/AUX/VBZ
# protection/NOUN/NN <--pobj-- for/ADP/IN
# at/ADP/IN <--prep-- protection/NOUN/NN
# this/DET/DT <--det-- point/NOUN/NN
# point/NOUN/NN <--pobj-- at/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# GoPro/PROPN/NNP <--nsubj-- claims/VERB/VBZ
# claims/VERB/VBZ <--ROOT-- claims/VERB/VBZ
# that/SCONJ/IN <--mark-- 's/AUX/VBZ
# it/PRON/PRP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ccomp-- claims/VERB/VBZ
# really/ADV/RB <--advmod-- difficult/ADJ/JJ
# difficult/ADJ/JJ <--acomp-- 's/AUX/VBZ
# to/PART/TO <--aux-- stitch/VERB/VB
# stitch/VERB/VB <--xcomp-- 's/AUX/VBZ
# underwater/ADJ/JJ <--amod-- footage/NOUN/NN
# footage/NOUN/NN <--dobj-- stitch/VERB/VB
# ,/PUNCT/, <--punct-- claims/VERB/VBZ
# but/CCONJ/CC <--cc-- claims/VERB/VBZ
# they/PRON/PRP <--nsubj-- promising/VERB/VBG
# are/AUX/VBP <--aux-- promising/VERB/VBG
# promising/VERB/VBG <--conj-- claims/VERB/VBZ
# some/DET/DT <--det-- sort/NOUN/NN
# sort/NOUN/NN <--dobj-- promising/VERB/VBG
# of/ADP/IN <--prep-- sort/NOUN/NN
# waterproof/ADJ/JJ <--amod-- housing/NOUN/NN
# housing/NOUN/NN <--pobj-- of/ADP/IN
# in/ADP/IN <--prep-- sort/NOUN/NN
# the/DET/DT <--det-- future/NOUN/NN
# future/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- promising/VERB/VBG
# The/DET/DT <--det-- screen/NOUN/NN
# screen/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# super/ADV/RB <--advmod-- responsive/ADJ/JJ
# responsive/ADJ/JJ <--acomp-- is/AUX/VBZ
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- is/AUX/VBZ
# you/PRON/PRP <--nsubj-- scroll/VERB/VB
# ca/VERB/MD <--aux-- scroll/VERB/VB
# n't/PART/RB <--neg-- scroll/VERB/VB
# scroll/VERB/VB <--conj-- is/AUX/VBZ
# around/ADP/IN <--prep-- scroll/VERB/VB
# your/PRON/PRP$ <--poss-- frame/NOUN/NN
# frame/NOUN/NN <--pobj-- around/ADP/IN
# in/ADP/IN <--prep-- scroll/VERB/VB
# 360/NUM/CD <--nummod-- mode/NOUN/NN
# mode/NOUN/NN <--pobj-- in/ADP/IN
# since/SCONJ/IN <--mark-- swiping/VERB/VBG
# the/DET/DT <--det-- screen/NOUN/NN
# screen/NOUN/NN <--nsubj-- swiping/VERB/VBG
# has/AUX/VBZ <--aux-- swiping/VERB/VBG
# swiping/VERB/VBG <--advcl-- scroll/VERB/VB
# gestures/NOUN/NNS <--dobj-- swiping/VERB/VBG
# such/ADJ/JJ <--amod-- as/SCONJ/IN
# as/SCONJ/IN <--prep-- gestures/NOUN/NNS
# swiping/VERB/VBG <--pcomp-- as/SCONJ/IN
# down/ADP/RP <--prt-- swiping/VERB/VBG
# to/PART/TO <--aux-- reach/VERB/VB
# reach/VERB/VB <--advcl-- swiping/VERB/VBG
# the/DET/DT <--det-- menu/NOUN/NN
# main/ADJ/JJ <--amod-- menu/NOUN/NN
# menu/NOUN/NN <--dobj-- reach/VERB/VB
# ./PUNCT/. <--punct-- scroll/VERB/VB
# You/PRON/PRP <--nsubj-- switch/VERB/VB
# can/AUX/MD <--aux-- switch/VERB/VB
# however/ADV/RB <--advmod-- switch/VERB/VB
# switch/VERB/VB <--ROOT-- switch/VERB/VB
# between/ADP/IN <--prep-- switch/VERB/VB
# lenses/NOUN/NNS <--pobj-- between/ADP/IN
# but/CCONJ/CC <--cc-- switch/VERB/VB
# only/ADV/RB <--advmod-- recording/VERB/VBG
# while/SCONJ/IN <--mark-- recording/VERB/VBG
# not/PART/RB <--neg-- recording/VERB/VBG
# recording/VERB/VBG <--conj-- switch/VERB/VB
# ./PUNCT/. <--punct-- switch/VERB/VB
# Once/SCONJ/IN <--mark-- hit/VERB/VBD
# you/PRON/PRP <--nsubj-- hit/VERB/VBD
# hit/VERB/VBD <--advcl-- has/AUX/VBZ
# that/DET/DT <--det-- button/NOUN/NN
# record/NOUN/NN <--compound-- button/NOUN/NN
# button/NOUN/NN <--dobj-- hit/VERB/VBD
# ,/PUNCT/, <--punct-- has/AUX/VBZ
# the/DET/DT <--det-- screen/NOUN/NN
# screen/NOUN/NN <--nsubj-- has/AUX/VBZ
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# no/DET/DT <--det-- functionality/NOUN/NN
# functionality/NOUN/NN <--dobj-- has/AUX/VBZ
# other/ADJ/JJ <--amod-- functionality/NOUN/NN
# than/SCONJ/IN <--prep-- has/AUX/VBZ
# just/ADV/RB <--advmod-- being/AUX/VBG
# being/AUX/VBG <--pcomp-- than/SCONJ/IN
# a/DET/DT <--det-- viewfinder/NOUN/NN
# viewfinder/NOUN/NN <--attr-- being/AUX/VBG
# to/ADP/IN <--prep-- viewfinder/NOUN/NN
# the/DET/DT <--det-- lens/NOUN/NN
# lens/NOUN/NN <--pobj-- to/ADP/IN
# that/PRON/WDT <--dobj-- chose/VERB/VBD
# you/PRON/PRP <--nsubj-- chose/VERB/VBD
# chose/VERB/VBD <--relcl-- lens/NOUN/NN
# before/ADP/IN <--prep-- chose/VERB/VBD
# rolling/VERB/VBG <--pcomp-- before/ADP/IN
# ./PUNCT/. <--punct-- has/AUX/VBZ
# The/DET/DT <--det-- image/NOUN/NN
# image/NOUN/NN <--nsubj-- stay/VERB/VB
# on/ADP/IN <--prep-- image/NOUN/NN
# the/DET/DT <--det-- screen/NOUN/NN
# screen/NOUN/NN <--pobj-- on/ADP/IN
# will/AUX/MD <--aux-- stay/VERB/VB
# however/ADV/RB <--advmod-- stay/VERB/VB
# stay/VERB/VB <--ROOT-- stay/VERB/VB
# level/NOUN/NN <--attr-- stay/VERB/VB
# with/ADP/IN <--prep-- level/NOUN/NN
# the/DET/DT <--det-- horizon/NOUN/NN
# horizon/NOUN/NN <--pobj-- with/ADP/IN
# no/ADV/RB <--neg-- matter/ADV/RB
# matter/ADV/RB <--npadvmod-- stay/VERB/VB
# which/PRON/WDT <--det-- way/NOUN/NN
# way/NOUN/NN <--npadvmod-- turn/VERB/VBP
# you/PRON/PRP <--nsubj-- turn/VERB/VBP
# turn/VERB/VBP <--advcl-- stay/VERB/VB
# the/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--dobj-- turn/VERB/VBP
# ./PUNCT/. <--punct-- stay/VERB/VB
# And/CCONJ/CC <--cc-- does/AUX/VBZ
# it/PRON/PRP <--nsubj-- does/AUX/VBZ
# does/AUX/VBZ <--ROOT-- does/AUX/VBZ
# so/ADV/RB <--advmod-- does/AUX/VBZ
# with/ADP/IN <--prep-- does/AUX/VBZ
# almost/ADV/RB <--advmod-- lag/NOUN/NN
# no/DET/DT <--det-- lag/NOUN/NN
# noticeable/ADJ/JJ <--amod-- lag/NOUN/NN
# lag/NOUN/NN <--pobj-- with/ADP/IN
# ./PUNCT/. <--punct-- does/AUX/VBZ
# If/SCONJ/IN <--mark-- lean/VERB/VBP
# you/PRON/PRP <--nsubj-- lean/VERB/VBP
# lean/VERB/VBP <--advcl-- give/VERB/VB
# into/ADP/IN <--prep-- lean/VERB/VBP
# that/DET/DT <--det-- look/VERB/VBP
# warped/VERB/VBN <--amod-- look/VERB/VBP
# ,/PUNCT/, <--punct-- look/VERB/VBP
# super/ADV/RB <--advmod-- fisheye/ADJ/JJ
# fisheye/ADJ/JJ <--nsubj-- look/VERB/VBP
# look/VERB/VBP <--pobj-- into/ADP/IN
# that/SCONJ/IN <--mark-- give/VERB/VB
# only/ADV/RB <--advmod-- 360/NUM/CD
# a/DET/DT <--quantmod-- 360/NUM/CD
# 360/NUM/CD <--nummod-- camera/NOUN/NN
# camera/NOUN/NN <--nsubj-- give/VERB/VB
# could/AUX/MD <--aux-- give/VERB/VB
# give/VERB/VB <--ccomp-- is/AUX/VBZ
# you/PRON/PRP <--dobj-- give/VERB/VB
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# the/DET/DT <--det-- footage/NOUN/NN
# footage/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# sick/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# Skin/NOUN/NN <--compound-- tones/NOUN/NNS
# tones/NOUN/NNS <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# true/ADJ/JJ <--acomp-- are/AUX/VBP
# to/ADP/IN <--prep-- true/ADJ/JJ
# life/NOUN/NN <--pobj-- to/ADP/IN
# and/CCONJ/CC <--cc-- are/AUX/VBP
# it/PRON/PRP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--conj-- are/AUX/VBP
# not/PART/RB <--neg-- 's/AUX/VBZ
# afraid/ADJ/JJ <--acomp-- 's/AUX/VBZ
# to/PART/TO <--aux-- overexpose/VERB/VB
# overexpose/VERB/VB <--xcomp-- afraid/ADJ/JJ
# the/DET/DT <--det-- highlights/NOUN/NNS
# highlights/NOUN/NNS <--dobj-- overexpose/VERB/VB
# of/ADP/IN <--prep-- highlights/NOUN/NNS
# it/PRON/PRP <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# I/PRON/PRP <--nsubj-- prefer/VERB/VBP
# prefer/VERB/VBP <--ROOT-- prefer/VERB/VBP
# this/DET/DT <--dobj-- prefer/VERB/VBP
# to/ADP/IN <--prep-- prefer/VERB/VBP
# the/DET/DT <--det-- grade/NOUN/NN
# flatter/ADJ/JJR <--amod-- grade/NOUN/NN
# color/NOUN/NN <--compound-- grade/NOUN/NN
# grade/NOUN/NN <--pobj-- to/ADP/IN
# of/ADP/IN <--prep-- grade/NOUN/NN
# the/DET/DT <--det-- X/PROPN/NNP
# One/NUM/CD <--compound-- X/PROPN/NNP
# X/PROPN/NNP <--pobj-- of/ADP/IN
# ,/PUNCT/, <--punct-- prefer/VERB/VBP
# especially/ADV/RB <--advmod-- for/ADP/IN
# for/ADP/IN <--prep-- prefer/VERB/VBP
# users/NOUN/NNS <--pobj-- for/ADP/IN
# who/PRON/WP <--nsubj-- be/AUX/VB
# wo/VERB/MD <--aux-- be/AUX/VB
# n't/PART/RB <--neg-- be/AUX/VB
# be/AUX/VB <--relcl-- users/NOUN/NNS
# color/NOUN/NN <--compound-- correcting/NOUN/NN
# correcting/NOUN/NN <--acomp-- be/AUX/VB
# ./PUNCT/. <--punct-- prefer/VERB/VBP
# And/CCONJ/CC <--cc-- find/VERB/VBP
# how/ADV/WRB <--advmod-- find/VERB/VBP
# even/ADV/RB <--advmod-- are/AUX/VBP
# if/SCONJ/IN <--mark-- are/AUX/VBP
# you/PRON/PRP <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--advcl-- find/VERB/VBP
# color/NOUN/NN <--compound-- correcting/NOUN/NN
# correcting/NOUN/NN <--acomp-- are/AUX/VBP
# ,/PUNCT/, <--punct-- find/VERB/VBP
# I/PRON/PRP <--nsubj-- find/VERB/VBP
# find/VERB/VBP <--ROOT-- find/VERB/VBP
# that/SCONJ/IN <--mark-- have/AUX/VBP
# the/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--nsubj-- have/AUX/VBP
# and/CCONJ/CC <--cc-- Max/PROPN/NNP
# the/DET/DT <--det-- X/NOUN/NNS
# One/NOUN/NN <--compound-- X/NOUN/NNS
# X/NOUN/NNS <--conj-- Max/PROPN/NNP
# have/AUX/VBP <--ccomp-- find/VERB/VBP
# very/ADV/RB <--advmod-- little/ADJ/JJ
# little/ADJ/JJ <--amod-- latitude/NOUN/NN
# latitude/NOUN/NN <--dobj-- have/AUX/VBP
# in/ADP/IN <--prep-- latitude/NOUN/NN
# the/DET/DT <--det-- process/NOUN/NN
# coloring/VERB/VBG <--amod-- process/NOUN/NN
# process/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- find/VERB/VBP
# Now/ADV/RB <--advmod-- gon/VERB/VBG
# ,/PUNCT/, <--punct-- gon/VERB/VBG
# if/SCONJ/IN <--mark-- gon/VERB/VBG
# you/PRON/PRP <--nsubj-- gon/VERB/VBG
# 're/AUX/VBP <--aux-- gon/VERB/VBG
# only/ADV/RB <--advmod-- gon/VERB/VBG
# gon/VERB/VBG <--advcl-- gon/VERB/VBG
# na/PART/TO <--aux-- showing/VERB/VBG
# be/AUX/VB <--aux-- showing/VERB/VBG
# showing/VERB/VBG <--xcomp-- gon/VERB/VBG
# these/DET/DT <--det-- photos/NOUN/NNS
# photos/NOUN/NNS <--dobj-- showing/VERB/VBG
# on/ADP/IN <--prep-- showing/VERB/VBG
# social/ADJ/JJ <--amod-- platforms/NOUN/NNS
# platforms/NOUN/NNS <--pobj-- on/ADP/IN
# that/PRON/WDT <--dobj-- look/VERB/VB
# you/PRON/PRP <--nsubj-- gon/VERB/VBG
# 're/AUX/VBP <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--ROOT-- gon/VERB/VBG
# na/PART/TO <--aux-- look/VERB/VB
# look/VERB/VB <--xcomp-- gon/VERB/VBG
# at/ADP/IN <--prep-- look/VERB/VB
# on/ADP/IN <--prep-- look/VERB/VB
# a/DET/DT <--det-- phone/NOUN/NN
# phone/NOUN/NN <--pobj-- on/ADP/IN
# ,/PUNCT/, <--punct-- phone/NOUN/NN
# who/PRON/WP <--nsubj-- cares/VERB/VBZ
# cares/VERB/VBZ <--relcl-- phone/NOUN/NN
# ,/PUNCT/, <--punct-- gon/VERB/VBG
# but/CCONJ/CC <--cc-- gon/VERB/VBG
# for/ADP/IN <--prep-- hope/VERB/VBP
# a/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--pobj-- for/ADP/IN
# that/PRON/WDT <--nsubj-- costs/VERB/VBZ
# costs/VERB/VBZ <--relcl-- camera/NOUN/NN
# $/SYM/$ <--nmod-- 500/NUM/CD
# 500/NUM/CD <--dobj-- costs/VERB/VBZ
# ,/PUNCT/, <--punct-- hope/VERB/VBP
# I/PRON/PRP <--nsubj-- hope/VERB/VBP
# hope/VERB/VBP <--conj-- gon/VERB/VBG
# it/PRON/PRP <--nsubj-- going/VERB/VBG
# 's/AUX/VBZ <--aux-- going/VERB/VBG
# going/VERB/VBG <--ccomp-- hope/VERB/VBP
# a/DET/DT <--det-- little/ADJ/JJ
# little/ADJ/JJ <--npadvmod-- further/ADV/RBR
# further/ADV/RBR <--advmod-- going/VERB/VBG
# than/SCONJ/IN <--prep-- further/ADV/RBR
# that/DET/DT <--pobj-- than/SCONJ/IN
# ./PUNCT/. <--punct-- hope/VERB/VBP
# (/PUNCT/-LRB- <--punct-- laughs/NOUN/NNS
# laughs/NOUN/NNS <--ROOT-- laughs/NOUN/NNS
# )/PUNCT/-RRB- <--punct-- laughs/NOUN/NNS
# ./PUNCT/. <--punct-- laughs/NOUN/NNS
# The/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--poss-- video/NOUN/NN
# 's/PART/POS <--case-- Max/PROPN/NNP
# 360/NUM/CD <--punct-- Max/PROPN/NNP
# °/PROPN/NNP <--nummod-- video/NOUN/NN
# video/NOUN/NN <--nsubjpass-- stabilized/VERB/VBN
# is/AUX/VBZ <--auxpass-- stabilized/VERB/VBN
# stabilized/VERB/VBN <--ROOT-- stabilized/VERB/VBN
# in/ADP/IN <--prep-- stabilized/VERB/VBN
# software/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- stabilized/VERB/VBN
# It/PRON/PRP <--nsubj-- bobs/VERB/VBP
# bobs/VERB/VBP <--ROOT-- bobs/VERB/VBP
# up/ADP/IN <--prt-- bobs/VERB/VBP
# and/CCONJ/CC <--cc-- up/ADP/IN
# down/ADV/RB <--conj-- up/ADP/IN
# as/SCONJ/IN <--mark-- expect/VERB/VB
# you/PRON/PRP <--nsubj-- expect/VERB/VB
# 'd/VERB/MD <--aux-- expect/VERB/VB
# expect/VERB/VB <--advcl-- bobs/VERB/VBP
# from/ADP/IN <--prep-- expect/VERB/VB
# walking/VERB/VBG <--pcomp-- from/ADP/IN
# and/CCONJ/CC <--cc-- bobs/VERB/VBP
# it/PRON/PRP <--nsubj-- be/AUX/VB
# can/AUX/MD <--aux-- be/AUX/VB
# be/AUX/VB <--conj-- bobs/VERB/VBP
# really/ADV/RB <--advmod-- be/AUX/VB
# jittery/ADJ/JJ <--acomp-- be/AUX/VB
# ,/PUNCT/, <--punct-- be/AUX/VB
# especially/ADV/RB <--advmod-- at/ADP/IN
# at/ADP/IN <--prep-- be/AUX/VB
# night/NOUN/NN <--pobj-- at/ADP/IN
# ./PUNCT/. <--punct-- be/AUX/VB
# The/DET/DT <--det-- stitching/NOUN/NN
# stitching/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# most/ADV/RBS <--advmod-- noticeable/ADJ/JJ
# noticeable/ADJ/JJ <--acomp-- is/AUX/VBZ
# at/ADP/IN <--prep-- noticeable/ADJ/JJ
# the/DET/DT <--det-- top/NOUN/NN
# top/NOUN/NN <--pobj-- at/ADP/IN
# and/CCONJ/CC <--cc-- top/NOUN/NN
# the/DET/DT <--det-- bottom/NOUN/NN
# bottom/NOUN/NN <--conj-- top/NOUN/NN
# of/ADP/IN <--prep-- bottom/NOUN/NN
# the/DET/DT <--det-- frame/NOUN/NN
# frame/NOUN/NN <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# And/CCONJ/CC <--cc-- 's/AUX/VBZ
# since/SCONJ/IN <--mark-- have/AUX/VBP
# most/ADJ/JJS <--nsubj-- have/AUX/VBP
# of/ADP/IN <--prep-- most/ADJ/JJS
# GoPro/PROPN/NNP <--poss-- mounts/NOUN/NNS
# 's/PART/POS <--case-- GoPro/PROPN/NNP
# mounts/NOUN/NNS <--pobj-- of/ADP/IN
# typically/ADV/RB <--advmod-- have/AUX/VBP
# have/AUX/VBP <--advcl-- 's/AUX/VBZ
# a/DET/DT <--det-- base/NOUN/NN
# wider/ADJ/JJR <--amod-- base/NOUN/NN
# base/NOUN/NN <--dobj-- have/AUX/VBP
# than/SCONJ/IN <--prep-- base/NOUN/NN
# the/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--pobj-- than/SCONJ/IN
# itself/PRON/PRP <--appos-- camera/NOUN/NN
# ,/PUNCT/, <--punct-- 's/AUX/VBZ
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# almost/ADV/RB <--advmod-- always/ADV/RB
# always/ADV/RB <--advmod-- 's/AUX/VBZ
# a/DET/DT <--det-- bit/NOUN/NN
# bit/NOUN/NN <--attr-- 's/AUX/VBZ
# of/ADP/IN <--prep-- bit/NOUN/NN
# artifact/NOUN/NN <--pobj-- of/ADP/IN
# from/ADP/IN <--prep-- bit/NOUN/NN
# the/DET/DT <--det-- mount/PROPN/NNP
# mount/PROPN/NNP <--pobj-- from/ADP/IN
# in/ADP/IN <--prep-- bit/NOUN/NN
# the/DET/DT <--det-- footage/NOUN/NN
# footage/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# Over/ADP/IN <--prep-- is/AUX/VBZ
# -/PUNCT/: <--punct-- Over/ADP/IN
# all/DET/DT <--pobj-- Over/ADP/IN
# though/ADV/RB <--advmod-- is/AUX/VBZ
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# once/SCONJ/IN <--mark-- export/VERB/VBP
# you/PRON/PRP <--nsubj-- export/VERB/VBP
# export/VERB/VBP <--advcl-- is/AUX/VBZ
# the/DET/DT <--det-- footage/NOUN/NN
# 360-degree/NUM/CD <--nummod-- footage/NOUN/NN
# footage/NOUN/NN <--dobj-- export/VERB/VBP
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# the/DET/DT <--det-- stitch/NOUN/NN
# stitch/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# pretty/ADV/RB <--advmod-- clean/ADJ/JJ
# clean/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# The/DET/DT <--det-- audio/NOUN/NN
# audio/NOUN/NN <--nsubj-- is/AUX/VBZ
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# however/ADV/RB <--advmod-- is/AUX/VBZ
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# probably/ADV/RB <--advmod-- is/AUX/VBZ
# the/DET/DT <--det-- best/ADJ/JJS
# best/ADJ/JJS <--attr-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- seen/VERB/VBN
# 've/AUX/VB <--aux-- seen/VERB/VBN
# seen/VERB/VBN <--relcl-- best/ADJ/JJS
# on/ADP/IN <--prep-- seen/VERB/VBN
# a/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--pobj-- on/ADP/IN
# this/DET/DT <--det-- size/NOUN/NN
# size/NOUN/NN <--dobj-- seen/VERB/VBN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# The/DET/DT <--det-- reduction/NOUN/NN
# wind/NOUN/NN <--compound-- reduction/NOUN/NN
# reduction/NOUN/NN <--nsubj-- add/VERB/VB
# can/AUX/MD <--aux-- add/VERB/VB
# add/VERB/VB <--ROOT-- add/VERB/VB
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--dobj-- add/VERB/VB
# of/ADP/IN <--prep-- lot/NOUN/NN
# compression/NOUN/NN <--pobj-- of/ADP/IN
# ,/PUNCT/, <--punct-- add/VERB/VB
# and/CCONJ/CC <--cc-- add/VERB/VB
# enough/ADJ/JJ <--amod-- wind/NOUN/NN
# wind/NOUN/NN <--nsubj-- sound/VERB/VB
# can/AUX/MD <--aux-- sound/VERB/VB
# sound/VERB/VB <--conj-- add/VERB/VB
# like/SCONJ/IN <--prep-- sound/VERB/VB
# ,/PUNCT/, <--punct-- sound/VERB/VB
# well/INTJ/UH <--intj-- sound/VERB/VB
# this/DET/DT <--intj-- sound/VERB/VB
# ,/PUNCT/, <--punct-- sound/VERB/VB
# (/PUNCT/-LRB- <--punct-- blowing/VERB/VBG
# wind/NOUN/NN <--nsubj-- blowing/VERB/VBG
# blowing/VERB/VBG <--parataxis-- sound/VERB/VB
# )/PUNCT/-RRB- <--punct-- blowing/VERB/VBG
# Guys/NOUN/NNS <--npadvmod-- 's/AUX/VBZ
# ,/PUNCT/, <--punct-- 's/AUX/VBZ
# when/ADV/WRB <--advmod-- say/VERB/VBP
# I/PRON/PRP <--nsubj-- say/VERB/VBP
# say/VERB/VBP <--advcl-- 's/AUX/VBZ
# it/PRON/PRP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ccomp-- say/VERB/VBP
# windy/ADJ/JJ <--acomp-- 's/AUX/VBZ
# out/ADP/RP <--prt-- windy/ADJ/JJ
# ,/PUNCT/, <--punct-- 's/AUX/VBZ
# it/PRON/PRP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# like/INTJ/UH <--intj-- 's/AUX/VBZ
# actually/ADV/RB <--advmod-- 's/AUX/VBZ
# very/ADV/RB <--advmod-- windy/ADJ/JJ
# windy/ADJ/JJ <--acomp-- 's/AUX/VBZ
# out/ADP/RP <--prt-- windy/ADJ/JJ
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# I/PRON/PRP <--nsubj-- am/AUX/VBP
# am/AUX/VBP <--ROOT-- am/AUX/VBP
# about/ADJ/JJ <--acomp-- am/AUX/VBP
# to/PART/TO <--aux-- blow/VERB/VB
# blow/VERB/VB <--xcomp-- about/ADJ/JJ
# over/ADP/RP <--prt-- blow/VERB/VB
# ./PUNCT/. <--punct-- am/AUX/VBP
# This/DET/DT <--nsubj-- make/VERB/VB
# might/AUX/MD <--aux-- make/VERB/VB
# make/VERB/VB <--ROOT-- make/VERB/VB
# some/DET/DT <--det-- footage/NOUN/NN
# really/ADV/RB <--advmod-- good/ADJ/JJ
# good/ADJ/JJ <--amod-- footage/NOUN/NN
# footage/NOUN/NN <--dobj-- make/VERB/VB
# as/SCONJ/IN <--mark-- fly/VERB/VBP
# I/PRON/PRP <--nsubj-- fly/VERB/VBP
# fly/VERB/VBP <--advcl-- make/VERB/VB
# away/ADV/RB <--advmod-- fly/VERB/VBP
# ./PUNCT/. <--punct-- make/VERB/VB
# But/CCONJ/CC <--cc-- reduces/VERB/VBZ
# when/ADV/WRB <--advmod-- 're/AUX/VBP
# you/PRON/PRP <--nsubj-- 're/AUX/VBP
# 're/AUX/VBP <--advcl-- reduces/VERB/VBZ
# not/PART/RB <--neg-- 're/AUX/VBP
# in/ADP/IN <--prep-- 're/AUX/VBP
# 25-mile/NUM/CD <--pobj-- in/ADP/IN
# an/DET/DT <--det-- hour/NOUN/NN
# hour/NOUN/NN <--compound-- wind/NOUN/NN
# wind/NOUN/NN <--pobj-- in/ADP/IN
# ,/PUNCT/, <--punct-- reduces/VERB/VBZ
# it/PRON/PRP <--nsubj-- reduces/VERB/VBZ
# actually/ADV/RB <--advmod-- reduces/VERB/VBZ
# reduces/VERB/VBZ <--ROOT-- reduces/VERB/VBZ
# the/DET/DT <--det-- sound/NOUN/NN
# sound/NOUN/NN <--dobj-- reduces/VERB/VBZ
# of/ADP/IN <--prep-- sound/NOUN/NN
# wind/NOUN/NN <--pobj-- of/ADP/IN
# while/SCONJ/IN <--mark-- prioritizing/VERB/VBG
# prioritizing/VERB/VBG <--advcl-- reduces/VERB/VBZ
# voices/NOUN/NNS <--dobj-- prioritizing/VERB/VBG
# ./PUNCT/. <--punct-- reduces/VERB/VBZ
# So/ADV/RB <--advmod-- love/VERB/VBP
# while/SCONJ/IN <--mark-- hiking/VERB/VBG
# hiking/VERB/VBG <--advcl-- love/VERB/VBP
# with/ADP/IN <--prep-- hiking/VERB/VBG
# Alex/PROPN/NNP <--pobj-- with/ADP/IN
# ,/PUNCT/, <--punct-- love/VERB/VBP
# I/PRON/PRP <--nsubj-- love/VERB/VBP
# love/VERB/VBP <--ROOT-- love/VERB/VBP
# that/SCONJ/IN <--mark-- picked/VERB/VBD
# the/DET/DT <--det-- GoPro/PROPN/NNP
# GoPro/PROPN/NNP <--nsubj-- picked/VERB/VBD
# picked/VERB/VBD <--ccomp-- love/VERB/VBP
# up/ADP/RP <--prt-- picked/VERB/VBD
# on/ADP/IN <--prep-- picked/VERB/VBD
# the/DET/DT <--det-- crickets/NOUN/NNS
# crickets/NOUN/NNS <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- crickets/NOUN/NNS
# footsteps/NOUN/NNS <--conj-- crickets/NOUN/NNS
# ,/PUNCT/, <--punct-- picked/VERB/VBD
# while/SCONJ/IN <--mark-- keeping/VERB/VBG
# also/ADV/RB <--advmod-- keeping/VERB/VBG
# keeping/VERB/VBG <--advcl-- picked/VERB/VBD
# our/PRON/PRP$ <--poss-- voices/NOUN/NNS
# voices/NOUN/NNS <--dobj-- keeping/VERB/VBG
# at/ADP/IN <--prep-- keeping/VERB/VBG
# the/DET/DT <--det-- forefront/NOUN/NN
# forefront/NOUN/NN <--pobj-- at/ADP/IN
# no/ADV/RB <--neg-- matter/ADV/RB
# matter/ADV/RB <--advmod-- keeping/VERB/VBG
# where/ADV/WRB <--advmod-- was/AUX/VBD
# the/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--nsubj-- was/AUX/VBD
# was/AUX/VBD <--ccomp-- matter/ADV/RB
# in/ADP/IN <--prep-- was/AUX/VBD
# space/NOUN/NN <--pobj-- in/ADP/IN
# ./PUNCT/. <--punct-- love/VERB/VBP
# ♪/PROPN/NNP <--ROOT-- ♪/PROPN/NNP
# Yeah/INTJ/UH <--ROOT-- Yeah/INTJ/UH
# ,/PUNCT/, <--punct-- Yeah/INTJ/UH
# and/CCONJ/CC <--cc-- think/VERB/VBP
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--ROOT-- think/VERB/VBP
# it/PRON/PRP <--nsubj-- gon/VERB/VBG
# 's/AUX/VBZ <--aux-- gon/VERB/VBG
# gon/VERB/VBG <--ccomp-- think/VERB/VBP
# na/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- gon/VERB/VBG
# a/DET/DT <--det-- time/NOUN/NN
# long/ADJ/JJ <--amod-- time/NOUN/NN
# ,/PUNCT/, <--punct-- time/NOUN/NN
# long/ADJ/JJ <--amod-- time/NOUN/NN
# time/NOUN/NN <--attr-- be/AUX/VB
# ♪/NOUN/NN <--punct-- think/VERB/VBP
# And/CCONJ/CC <--cc-- are/AUX/VBP
# then/ADV/RB <--advmod-- are/AUX/VBP
# there/PRON/EX <--expl-- are/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# those/DET/DT <--det-- photos/NOUN/NNS
# PowerPano/PROPN/NNP <--compound-- photos/NOUN/NNS
# photos/NOUN/NNS <--attr-- are/AUX/VBP
# ./PUNCT/. <--punct-- are/AUX/VBP
# I/PRON/PRP <--nsubj-- got/VERB/VBD
# got/VERB/VBD <--ccomp-- had/AUX/VBD
# ta/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- got/VERB/VBD
# honest/ADJ/JJ <--amod-- guys/NOUN/NNS
# guys/NOUN/NNS <--attr-- be/AUX/VB
# ,/PUNCT/, <--punct-- had/AUX/VBD
# I/PRON/PRP <--nsubj-- had/AUX/VBD
# had/AUX/VBD <--ROOT-- had/AUX/VBD
# a/DET/DT <--det-- time/NOUN/NN
# tough/ADJ/JJ <--amod-- time/NOUN/NN
# time/NOUN/NN <--dobj-- had/AUX/VBD
# not/PART/RB <--neg-- showing/VERB/VBG
# showing/VERB/VBG <--acl-- time/NOUN/NN
# you/PRON/PRP <--dative-- showing/VERB/VBG
# these/DET/DT <--det-- photos/NOUN/NNS
# photos/NOUN/NNS <--dobj-- showing/VERB/VBG
# before/ADP/IN <--mark-- dropped/VERB/VBD
# this/DET/DT <--det-- video/NOUN/NN
# video/NOUN/NN <--nsubj-- dropped/VERB/VBD
# dropped/VERB/VBD <--advcl-- showing/VERB/VBG
# ./PUNCT/. <--punct-- had/AUX/VBD
# I/PRON/PRP <--nsubj-- mean/VERB/VBP
# mean/VERB/VBP <--parataxis-- make/VERB/VBP
# first/ADV/RB <--advmod-- mean/VERB/VBP
# and/CCONJ/CC <--cc-- first/ADV/RB
# foremost/ADV/RB <--conj-- first/ADV/RB
# ,/PUNCT/, <--punct-- make/VERB/VBP
# they/PRON/PRP <--nsubj-- make/VERB/VBP
# make/VERB/VBP <--ROOT-- make/VERB/VBP
# taking/VERB/VBG <--xcomp-- make/VERB/VBP
# a/DET/DT <--det-- photo/NOUN/NN
# panoramic/ADJ/JJ <--amod-- photo/NOUN/NN
# photo/NOUN/NN <--dobj-- taking/VERB/VBG
# a/DET/DT <--det-- lot/NOUN/NN
# lot/NOUN/NN <--npadvmod-- easier/ADJ/JJR
# easier/ADJ/JJR <--advmod-- taking/VERB/VBG
# ./PUNCT/. <--punct-- make/VERB/VBP
# And/CCONJ/CC <--cc-- have/AUX/VB
# you/PRON/PRP <--nsubj-- have/AUX/VB
# do/AUX/VBP <--aux-- have/AUX/VB
# n't/PART/RB <--neg-- have/AUX/VB
# have/AUX/VB <--ROOT-- have/AUX/VB
# to/PART/TO <--aux-- stand/VERB/VB
# stand/VERB/VB <--xcomp-- have/AUX/VB
# there/ADV/RB <--advmod-- stand/VERB/VB
# and/CCONJ/CC <--cc-- stand/VERB/VB
# slowly/ADV/RB <--conj-- stand/VERB/VB
# and/CCONJ/CC <--cc-- slowly/ADV/RB
# robotically/ADV/RB <--advmod-- move/VERB/VB
# move/VERB/VB <--conj-- slowly/ADV/RB
# your/PRON/PRP$ <--poss-- phone/NOUN/NN
# phone/NOUN/NN <--dobj-- move/VERB/VB
# across/ADP/IN <--prep-- move/VERB/VB
# the/DET/DT <--det-- landscape/NOUN/NN
# landscape/NOUN/NN <--pobj-- across/ADP/IN
# ./PUNCT/. <--punct-- have/AUX/VB
# I/PRON/PRP <--nsubj-- was/AUX/VBD
# was/AUX/VBD <--ROOT-- was/AUX/VBD
# really/ADV/RB <--advmod-- surprised/ADJ/JJ
# surprised/ADJ/JJ <--acomp-- was/AUX/VBD
# at/ADP/IN <--prep-- surprised/ADJ/JJ
# how/ADV/WRB <--advmod-- crisp/ADJ/JJ
# crisp/ADJ/JJ <--acomp-- turned/VERB/VBD
# these/DET/DT <--det-- photos/NOUN/NNS
# photos/NOUN/NNS <--nsubj-- turned/VERB/VBD
# turned/VERB/VBD <--pcomp-- at/ADP/IN
# out/ADP/RP <--prt-- turned/VERB/VBD
# to/ADP/IN <--prep-- turned/VERB/VBD
# ./PUNCT/. <--punct-- was/AUX/VBD
# Even/ADV/RB <--advmod-- on/ADP/IN
# on/ADP/IN <--prep-- look/VERB/VBP
# a/DET/DT <--det-- desktop/NOUN/NN
# desktop/NOUN/NN <--pobj-- on/ADP/IN
# ,/PUNCT/, <--punct-- look/VERB/VBP
# they/PRON/PRP <--nsubj-- look/VERB/VBP
# still/ADV/RB <--advmod-- look/VERB/VBP
# look/VERB/VBP <--ROOT-- look/VERB/VBP
# really/ADV/RB <--advmod-- cool/ADJ/JJ
# cool/ADJ/JJ <--acomp-- look/VERB/VBP
# ./PUNCT/. <--punct-- look/VERB/VBP
# The/DET/DT <--det-- feature/NOUN/NN
# time/NOUN/NN <--compound-- feature/NOUN/NN
# warp/NOUN/NN <--compound-- feature/NOUN/NN
# feature/NOUN/NN <--nsubj-- is/AUX/VBZ
# in/ADP/IN <--prep-- feature/NOUN/NN
# 360/NUM/CD <--nummod-- mode/NOUN/NN
# mode/NOUN/NN <--pobj-- in/ADP/IN
# ,/PUNCT/, <--punct-- mode/NOUN/NN
# which/PRON/WDT <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--relcl-- mode/NOUN/NN
# when/ADV/WRB <--advmod-- records/VERB/VBZ
# the/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--nsubj-- records/VERB/VBZ
# just/ADV/RB <--advmod-- records/VERB/VBZ
# records/VERB/VBZ <--advcl-- is/AUX/VBZ
# the/DET/DT <--det-- time/NOUN/NN
# time/NOUN/NN <--compound-- lapse/PROPN/NNP
# lapse/PROPN/NNP <--dobj-- records/VERB/VBZ
# ,/PUNCT/, <--punct-- mode/NOUN/NN
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# really/ADV/RB <--advmod-- cool/ADJ/JJ
# cool/ADJ/JJ <--acomp-- is/AUX/VBZ
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# but/CCONJ/CC <--cc-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--conj-- is/AUX/VBZ
# a/DET/DT <--det-- killer/NOUN/NN
# total/ADJ/JJ <--amod-- killer/NOUN/NN
# battery/NOUN/NN <--compound-- killer/NOUN/NN
# killer/NOUN/NN <--attr-- 's/AUX/VBZ
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# I/PRON/PRP <--nsubj-- saw/VERB/VBD
# saw/VERB/VBD <--ROOT-- saw/VERB/VBD
# my/PRON/PRP$ <--poss-- battery/NOUN/NN
# battery/NOUN/NN <--nsubj-- drop/VERB/VB
# drop/VERB/VB <--ccomp-- saw/VERB/VBD
# 15/NUM/CD <--nummod-- %/NOUN/NN
# %/NOUN/NN <--npadvmod-- drop/VERB/VB
# off/ADP/IN <--prep-- drop/VERB/VB
# a/DET/DT <--det-- charge/NOUN/NN
# fresh/ADJ/JJ <--amod-- charge/NOUN/NN
# charge/NOUN/NN <--pobj-- off/ADP/IN
# while/SCONJ/IN <--mark-- shooting/VERB/VBG
# shooting/VERB/VBG <--advcl-- drop/VERB/VB
# this/DET/DT <--det-- time/NOUN/NN
# time/NOUN/NN <--compound-- warp/NOUN/NN
# warp/NOUN/NN <--advmod-- shooting/VERB/VBG
# ./PUNCT/. <--punct-- saw/VERB/VBD
# And/CCONJ/CC <--cc-- let/VERB/VBP
# I/PRON/PRP <--nsubj-- let/VERB/VBP
# let/VERB/VBP <--ROOT-- let/VERB/VBP
# it/PRON/PRP <--nsubj-- record/VERB/VB
# record/VERB/VB <--ccomp-- let/VERB/VBP
# for/ADP/IN <--prep-- record/VERB/VB
# all/DET/DT <--pobj-- for/ADP/IN
# of/ADP/IN <--prep-- all/DET/DT
# 10/NUM/CD <--nummod-- minutes/NOUN/NNS
# minutes/NOUN/NNS <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- let/VERB/VBP
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--ROOT-- think/VERB/VBP
# it/PRON/PRP <--nsubj-- help/VERB/VB
# would/AUX/MD <--aux-- help/VERB/VB
# help/VERB/VB <--ccomp-- think/VERB/VBP
# if/SCONJ/IN <--mark-- go/VERB/VB
# the/DET/DT <--det-- screen/NOUN/NN
# screen/NOUN/NN <--nsubj-- go/VERB/VB
# would/AUX/MD <--aux-- go/VERB/VB
# go/VERB/VB <--ccomp-- help/VERB/VB
# off/ADP/RP <--prt-- go/VERB/VB
# a/DET/DT <--det-- bit/NOUN/NN
# bit/NOUN/NN <--npadvmod-- sooner/ADV/RBR
# sooner/ADV/RBR <--advmod-- go/VERB/VB
# while/SCONJ/IN <--mark-- shooting/VERB/VBG
# shooting/VERB/VBG <--advcl-- go/VERB/VB
# these/DET/DT <--dobj-- shooting/VERB/VBG
# to/PART/TO <--aux-- save/VERB/VB
# save/VERB/VB <--advcl-- shooting/VERB/VBG
# some/DET/DT <--det-- battery/NOUN/NN
# battery/NOUN/NN <--dobj-- save/VERB/VB
# ./PUNCT/. <--punct-- think/VERB/VBP
# Otherwise/ADV/RB <--advmod-- is/AUX/VBZ
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# the/DET/DT <--det-- performance/NOUN/NN
# battery/NOUN/NN <--compound-- performance/NOUN/NN
# performance/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# on/ADP/IN <--prep-- is/AUX/VBZ
# par/NOUN/NN <--pobj-- on/ADP/IN
# with/ADP/IN <--prep-- par/NOUN/NN
# the/DET/DT <--det-- Hero8/PROPN/NNP
# Hero8/PROPN/NNP <--pobj-- with/ADP/IN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# Even/ADV/RB <--advmod-- is/AUX/VBZ
# though/SCONJ/IN <--mark-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# a/DET/DT <--det-- battery/NOUN/NN
# different/ADJ/JJ <--amod-- battery/NOUN/NN
# battery/NOUN/NN <--attr-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# So/ADV/RB <--advmod-- need/VERB/VB
# yes/INTJ/UH <--intj-- need/VERB/VB
# ,/PUNCT/, <--punct-- need/VERB/VB
# you/PRON/PRP <--nsubj-- need/VERB/VB
# will/AUX/MD <--aux-- need/VERB/VB
# need/VERB/VB <--ROOT-- need/VERB/VB
# to/PART/TO <--aux-- buy/VERB/VB
# buy/VERB/VB <--xcomp-- need/VERB/VB
# extra/ADJ/JJ <--amod-- spares/NOUN/NNS
# spares/NOUN/NNS <--dobj-- buy/VERB/VB
# if/SCONJ/IN <--mark-- plan/VERB/VBP
# you/PRON/PRP <--nsubj-- plan/VERB/VBP
# plan/VERB/VBP <--advcl-- buy/VERB/VB
# on/ADP/IN <--prep-- plan/VERB/VBP
# heavy/ADJ/JJ <--amod-- use/NOUN/NN
# use/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- need/VERB/VB
# I/PRON/PRP <--nsubj-- was/AUX/VBD
# was/AUX/VBD <--ROOT-- was/AUX/VBD
# able/ADJ/JJ <--acomp-- was/AUX/VBD
# to/PART/TO <--aux-- get/AUX/VB
# get/AUX/VB <--xcomp-- able/ADJ/JJ
# through/ADP/IN <--prep-- get/AUX/VB
# a/DET/DT <--det-- day/NOUN/NN
# full/ADJ/JJ <--amod-- day/NOUN/NN
# day/NOUN/NN <--pobj-- through/ADP/IN
# of/ADP/IN <--prep-- day/NOUN/NN
# heavy/ADJ/JJ <--amod-- use/NOUN/NN
# use/NOUN/NN <--pobj-- of/ADP/IN
# using/VERB/VBG <--advcl-- get/AUX/VB
# two/NUM/CD <--dobj-- using/VERB/VBG
# of/ADP/IN <--prep-- two/NUM/CD
# these/DET/DT <--det-- batteries/NOUN/NNS
# batteries/NOUN/NNS <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- was/AUX/VBD
# 360/NUM/CD <--nummod-- cameras/NOUN/NNS
# cameras/NOUN/NNS <--nsubj-- are/AUX/VBP
# are/AUX/VBP <--ROOT-- are/AUX/VBP
# only/ADV/RB <--advmod-- are/AUX/VBP
# accessible/ADJ/JJ <--acomp-- are/AUX/VBP
# though/ADV/RB <--advmod-- are/AUX/VBP
# if/SCONJ/IN <--mark-- do/AUX/VB
# you/PRON/PRP <--nsubj-- do/AUX/VB
# can/AUX/MD <--aux-- do/AUX/VB
# do/AUX/VB <--advcl-- are/AUX/VBP
# something/PRON/NN <--dobj-- do/AUX/VB
# with/ADP/IN <--prep-- do/AUX/VB
# the/DET/DT <--det-- footage/NOUN/NN
# footage/NOUN/NN <--pobj-- with/ADP/IN
# ./PUNCT/. <--punct-- are/AUX/VBP
# So/ADV/RB <--advmod-- has/AUX/VBZ
# the/DET/DT <--det-- software/NOUN/NN
# software/NOUN/NN <--nsubj-- has/AUX/VBZ
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# to/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- has/AUX/VBZ
# sound/ADJ/JJ <--acomp-- be/AUX/VB
# ,/PUNCT/, <--punct-- has/AUX/VBZ
# and/CCONJ/CC <--cc-- has/AUX/VBZ
# GoPro/PROPN/NNP <--poss-- app/NOUN/NN
# 's/PART/POS <--case-- GoPro/PROPN/NNP
# app/NOUN/NN <--nsubj-- makes/VERB/VBZ
# makes/VERB/VBZ <--conj-- has/AUX/VBZ
# it/PRON/PRP <--nsubj-- easy/ADJ/JJ
# really/ADV/RB <--advmod-- easy/ADJ/JJ
# easy/ADJ/JJ <--ccomp-- makes/VERB/VBZ
# to/PART/TO <--aux-- edit/VERB/VB
# edit/VERB/VB <--xcomp-- easy/ADJ/JJ
# this/DET/DT <--det-- footage/NOUN/NN
# footage/NOUN/NN <--dobj-- edit/VERB/VB
# ./PUNCT/. <--punct-- makes/VERB/VBZ
# Max/PROPN/NNP <--nsubj-- uses/VERB/VBZ
# uses/VERB/VBZ <--ROOT-- uses/VERB/VBZ
# the/DET/DT <--det-- app/NOUN/NN
# same/ADJ/JJ <--amod-- app/NOUN/NN
# GoPro/PROPN/NNP <--compound-- app/NOUN/NN
# app/NOUN/NN <--dobj-- uses/VERB/VBZ
# as/SCONJ/IN <--prep-- uses/VERB/VBZ
# the/DET/DT <--det-- Heroes/PROPN/NNPS
# Heroes/PROPN/NNPS <--pobj-- as/SCONJ/IN
# ./PUNCT/. <--punct-- uses/VERB/VBZ
# Now/ADV/RB <--advmod-- 'm/AUX/VBP
# ,/PUNCT/, <--punct-- 'm/AUX/VBP
# I/PRON/PRP <--nsubj-- 'm/AUX/VBP
# 'm/AUX/VBP <--ROOT-- 'm/AUX/VBP
# no/DET/DT <--det-- stranger/NOUN/NN
# stranger/NOUN/NN <--attr-- 'm/AUX/VBP
# to/ADP/IN <--prep-- stranger/NOUN/NN
# keyframes/NOUN/NNS <--pobj-- to/ADP/IN
# ,/PUNCT/, <--punct-- 'm/AUX/VBP
# but/CCONJ/CC <--cc-- 'm/AUX/VBP
# I/PRON/PRP <--nsubj-- think/VERB/VBP
# think/VERB/VBP <--conj-- 'm/AUX/VBP
# even/ADV/RB <--advmod-- director/NOUN/NN
# a/DET/DT <--det-- director/NOUN/NN
# casual/ADJ/JJ <--amod-- director/NOUN/NN
# non/ADJ/JJ <--dep-- -/ADJ/JJ
# -/ADJ/JJ <--dep-- video/ADJ/JJ
# video/ADJ/JJ <--amod-- director/NOUN/NN
# director/NOUN/NN <--nsubj-- edit/VERB/VB
# from/ADP/IN <--prep-- director/NOUN/NN
# the/DET/DT <--det-- verge.com/PROPN/NNP
# verge.com/PROPN/NNP <--pobj-- from/ADP/IN
# could/AUX/MD <--aux-- edit/VERB/VB
# edit/VERB/VB <--ccomp-- think/VERB/VBP
# the/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--poss-- footage/NOUN/NN
# 's/PART/POS <--case-- Max/PROPN/NNP
# 360/NUM/CD <--nummod-- footage/NOUN/NN
# footage/NOUN/NN <--dobj-- edit/VERB/VB
# ./PUNCT/. <--punct-- think/VERB/VBP
# And/CCONJ/CC <--cc-- enjoyed/VERB/VBD
# I/PRON/PRP <--nsubj-- enjoyed/VERB/VBD
# actually/ADV/RB <--advmod-- enjoyed/VERB/VBD
# enjoyed/VERB/VBD <--ROOT-- enjoyed/VERB/VBD
# editing/VERB/VBG <--xcomp-- enjoyed/VERB/VBD
# it/PRON/PRP <--dobj-- editing/VERB/VBG
# on/ADP/IN <--prep-- editing/VERB/VBG
# the/DET/DT <--det-- app/NOUN/NN
# app/NOUN/NN <--pobj-- on/ADP/IN
# ./PUNCT/. <--punct-- enjoyed/VERB/VBD
# GoPro/PROPN/NNP <--nsubj-- has/AUX/VBZ
# also/ADV/RB <--advmod-- has/AUX/VBZ
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# a/DET/DT <--det-- app/NOUN/NN
# 360/NUM/CD <--nummod-- app/NOUN/NN
# desktop/NOUN/NN <--compound-- app/NOUN/NN
# app/NOUN/NN <--dobj-- has/AUX/VBZ
# called/VERB/VBN <--acl-- app/NOUN/NN
# GoPro/PROPN/NNP <--compound-- Player/PROPN/NNP
# Player/PROPN/NNP <--oprd-- called/VERB/VBN
# ,/PUNCT/, <--punct-- Player/PROPN/NNP
# which/PRON/WDT <--nsubj-- mirrors/VERB/VBZ
# mirrors/VERB/VBZ <--relcl-- Player/PROPN/NNP
# ...
# there/PRON/EX <--expl-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# this/DET/DT <--det-- mode/NOUN/NN
# whole/ADJ/JJ <--amod-- mode/NOUN/NN
# other/ADJ/JJ <--amod-- mode/NOUN/NN
# mode/NOUN/NN <--attr-- 's/AUX/VBZ
# on/ADP/IN <--prep-- mode/NOUN/NN
# the/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--pobj-- on/ADP/IN
# called/VERB/VBN <--acl-- mode/NOUN/NN
# Hero/PROPN/NNP <--compound-- mode/NOUN/NN
# mode/NOUN/NN <--oprd-- called/VERB/VBN
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# And/CCONJ/CC <--cc-- 's/AUX/VBZ
# it/PRON/PRP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# basically/ADV/RB <--advmod-- 's/AUX/VBZ
# just/ADV/RB <--advmod-- when/ADV/WRB
# when/ADV/WRB <--advmod-- using/VERB/VBG
# the/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--nsubj-- using/VERB/VBG
# 's/PART/POS <--aux-- using/VERB/VBG
# using/VERB/VBG <--advcl-- 's/AUX/VBZ
# one/NUM/CD <--nummod-- lens/NOUN/NN
# lens/NOUN/NN <--dobj-- using/VERB/VBG
# as/SCONJ/IN <--mark-- opposed/VERB/VBN
# opposed/VERB/VBN <--advcl-- using/VERB/VBG
# to/ADP/IN <--prep-- opposed/VERB/VBN
# two/NUM/CD <--pobj-- to/ADP/IN
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# It/PRON/PRP <--nsubj-- has/AUX/VBZ
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# more/ADV/RBR <--amod-- controls/NOUN/NNS
# mic/ADJ/JJ <--compound-- controls/NOUN/NNS
# controls/NOUN/NNS <--dobj-- has/AUX/VBZ
# and/CCONJ/CC <--cc-- has/AUX/VBZ
# it/PRON/PRP <--nsubj-- boasts/VERB/VBZ
# even/ADV/RB <--advmod-- boasts/VERB/VBZ
# boasts/VERB/VBZ <--conj-- has/AUX/VBZ
# GoPro/PROPN/NNP <--poss-- video/NOUN/NN
# 's/PART/POS <--case-- GoPro/PROPN/NNP
# most/ADV/RBS <--advmod-- stable/ADJ/JJ
# stable/ADJ/JJ <--amod-- video/NOUN/NN
# video/NOUN/NN <--dobj-- boasts/VERB/VBZ
# called/VERB/VBN <--acl-- video/NOUN/NN
# Max/PROPN/NNP <--compound-- HyperSmooth/PROPN/NNP
# HyperSmooth/PROPN/NNP <--oprd-- called/VERB/VBN
# ./PUNCT/. <--punct-- boasts/VERB/VBZ
# And/CCONJ/CC <--cc-- has/AUX/VBZ
# it/PRON/PRP <--nsubj-- has/AUX/VBZ
# also/ADV/RB <--advmod-- has/AUX/VBZ
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# the/DET/DT <--det-- field/NOUN/NN
# widest/ADJ/JJS <--amod-- field/NOUN/NN
# field/NOUN/NN <--dobj-- has/AUX/VBZ
# of/ADP/IN <--prep-- field/NOUN/NN
# view/NOUN/NN <--pobj-- of/ADP/IN
# called/VERB/VBN <--acl-- field/NOUN/NN
# Max/PROPN/NNP <--compound-- SuperView/PROPN/NNP
# SuperView/PROPN/NNP <--oprd-- called/VERB/VBN
# ./PUNCT/. <--punct-- has/AUX/VBZ
# But/CCONJ/CC <--cc-- got/VERB/VBD
# I/PRON/PRP <--nsubj-- got/VERB/VBD
# got/VERB/VBD <--ROOT-- got/VERB/VBD
# ta/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--xcomp-- got/VERB/VBD
# honest/ADJ/JJ <--acomp-- be/AUX/VB
# ,/PUNCT/, <--punct-- got/VERB/VBD
# while/SCONJ/IN <--mark-- sound/VERB/VB
# it/PRON/PRP <--nsubj-- sound/VERB/VB
# does/AUX/VBZ <--aux-- sound/VERB/VB
# sound/VERB/VB <--advcl-- got/VERB/VBD
# good/ADJ/JJ <--acomp-- sound/VERB/VB
# and/CCONJ/CC <--cc-- sound/VERB/VB
# the/DET/DT <--det-- footage/NOUN/NN
# footage/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--conj-- sound/VERB/VB
# stable/ADJ/JJ <--acomp-- is/AUX/VBZ
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# the/DET/DT <--det-- fact/NOUN/NN
# fact/NOUN/NN <--nsubj-- is/AUX/VBZ
# that/SCONJ/IN <--mark-- maxes/VERB/VBZ
# it/PRON/PRP <--nsubj-- maxes/VERB/VBZ
# maxes/VERB/VBZ <--acl-- fact/NOUN/NN
# out/ADP/RP <--prt-- maxes/VERB/VBZ
# at/ADP/IN <--prep-- maxes/VERB/VBZ
# 1440p60/PROPN/NNP <--pobj-- at/ADP/IN
# is/AUX/VBZ <--advcl-- is/AUX/VBZ
# noticeable/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# Especially/ADV/RB <--advmod-- in/ADP/IN
# in/ADP/IN <--ROOT-- in/ADP/IN
# how/ADV/WRB <--advmod-- much/ADJ/JJ
# much/ADJ/JJ <--amod-- smoothing/NOUN/NN
# smoothing/NOUN/NN <--nsubjpass-- done/VERB/VBN
# is/AUX/VBZ <--aux-- done/VERB/VBN
# being/AUX/VBG <--auxpass-- done/VERB/VBN
# done/VERB/VBN <--pcomp-- in/ADP/IN
# when/ADV/WRB <--advmod-- is/AUX/VBZ
# the/DET/DT <--det-- subject/NOUN/NN
# subject/NOUN/NN <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--advcl-- done/VERB/VBN
# close/ADJ/JJ <--acomp-- is/AUX/VBZ
# to/ADP/IN <--prep-- close/ADJ/JJ
# the/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--pobj-- to/ADP/IN
# ./PUNCT/. <--punct-- in/ADP/IN
# I/PRON/PRP <--nsubj-- noticed/VERB/VBD
# also/ADV/RB <--advmod-- noticed/VERB/VBD
# noticed/VERB/VBD <--ROOT-- noticed/VERB/VBD
# the/DET/DT <--det-- camera/NOUN/NN
# camera/NOUN/NN <--nsubj-- struggled/VERB/VBD
# struggled/VERB/VBD <--ccomp-- noticed/VERB/VBD
# to/PART/TO <--aux-- keep/VERB/VB
# keep/VERB/VB <--xcomp-- struggled/VERB/VBD
# the/DET/DT <--det-- level/NOUN/NN
# footage/NOUN/NN <--compound-- level/NOUN/NN
# level/NOUN/NN <--dobj-- keep/VERB/VB
# with/ADP/IN <--prep-- keep/VERB/VB
# the/DET/DT <--det-- horizon/NOUN/NN
# horizon/NOUN/NN <--pobj-- with/ADP/IN
# ,/PUNCT/, <--punct-- keep/VERB/VB
# choosing/VERB/VBG <--advcl-- keep/VERB/VB
# to/PART/TO <--aux-- focus/VERB/VB
# instead/ADV/RB <--advmod-- focus/VERB/VB
# focus/VERB/VB <--xcomp-- choosing/VERB/VBG
# on/ADP/IN <--prep-- focus/VERB/VB
# keeping/VERB/VBG <--pcomp-- on/ADP/IN
# the/DET/DT <--det-- footage/NOUN/NN
# footage/NOUN/NN <--dobj-- keeping/VERB/VBG
# stable/ADJ/JJ <--oprd-- keeping/VERB/VBG
# ./PUNCT/. <--punct-- noticed/VERB/VBD
# So/ADV/RB <--advmod-- is/AUX/VBZ
# when/ADV/WRB <--advmod-- climbing/VERB/VBG
# climbing/VERB/VBG <--advcl-- is/AUX/VBZ
# down/ADP/RP <--prt-- climbing/VERB/VBG
# this/DET/DT <--det-- trail/NOUN/NN
# trail/NOUN/NN <--dobj-- climbing/VERB/VBG
# ,/PUNCT/, <--punct-- trail/NOUN/NN
# which/PRON/WDT <--nsubj-- be/AUX/VB
# to/PART/TO <--aux-- be/AUX/VB
# be/AUX/VB <--relcl-- trail/NOUN/NN
# fair/ADJ/JJ <--acomp-- be/AUX/VB
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# is/AUX/VBZ <--ccomp-- kept/VERB/VBD
# a/DET/DT <--det-- surface/NOUN/NN
# slanted/ADJ/JJ <--amod-- surface/NOUN/NN
# surface/NOUN/NN <--attr-- is/AUX/VBZ
# ,/PUNCT/, <--punct-- kept/VERB/VBD
# the/DET/DT <--det-- horizon/NOUN/NN
# horizon/NOUN/NN <--nsubj-- kept/VERB/VBD
# kept/VERB/VBD <--ROOT-- kept/VERB/VBD
# tilting/VERB/VBG <--xcomp-- kept/VERB/VBD
# further/ADV/RBR <--advmod-- tilting/VERB/VBG
# and/CCONJ/CC <--cc-- further/ADV/RBR
# further/ADV/RBR <--conj-- further/ADV/RBR
# from/ADP/IN <--prep-- tilting/VERB/VBG
# level/NOUN/NN <--pobj-- from/ADP/IN
# to/ADP/IN <--prep-- tilting/VERB/VBG
# almost/ADV/RB <--advmod-- point/NOUN/NN
# a/DET/DT <--det-- point/NOUN/NN
# dizzying/ADJ/JJ <--amod-- point/NOUN/NN
# point/NOUN/NN <--pobj-- to/ADP/IN
# ./PUNCT/. <--punct-- kept/VERB/VBD
# GoPro/PROPN/NNP <--nsubj-- become/VERB/VBN
# has/AUX/VBZ <--aux-- become/VERB/VBN
# become/VERB/VBN <--ROOT-- become/VERB/VBN
# a/DET/DT <--det-- name/NOUN/NN
# household/NOUN/NN <--compound-- name/NOUN/NN
# name/NOUN/NN <--attr-- become/VERB/VBN
# ./PUNCT/. <--punct-- become/VERB/VBN
# I/PRON/PRP <--nsubj-- mean/VERB/VBP
# mean/VERB/VBP <--parataxis-- specced/VERB/VBN
# they/PRON/PRP <--nsubjpass-- specced/VERB/VBN
# 're/AUX/VBP <--auxpass-- specced/VERB/VBN
# specced/VERB/VBN <--ROOT-- specced/VERB/VBN
# out/ADP/RP <--prt-- specced/VERB/VBN
# ,/PUNCT/, <--punct-- specced/VERB/VBN
# durable/ADJ/JJ <--amod-- beasts/NOUN/NNS
# ,/PUNCT/, <--punct-- beasts/NOUN/NNS
# tiny/ADJ/JJ <--amod-- beasts/NOUN/NNS
# ,/PUNCT/, <--punct-- beasts/NOUN/NNS
# portable/ADJ/JJ <--amod-- beasts/NOUN/NNS
# beasts/NOUN/NNS <--appos-- specced/VERB/VBN
# of/ADP/IN <--prep-- beasts/NOUN/NNS
# cameras/NOUN/NNS <--pobj-- of/ADP/IN
# ./PUNCT/. <--punct-- specced/VERB/VBN
# And/CCONJ/CC <--cc-- is/AUX/VBZ
# the/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# no/ADV/RB <--neg-- different/ADJ/JJ
# different/ADJ/JJ <--acomp-- is/AUX/VBZ
# ./PUNCT/. <--punct-- is/AUX/VBZ
# And/CCONJ/CC <--cc-- has/AUX/VBZ
# while/SCONJ/IN <--mark-- has/AUX/VBZ
# the/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--nsubj-- has/AUX/VBZ
# has/AUX/VBZ <--advcl-- has/AUX/VBZ
# great/ADJ/JJ <--amod-- features/NOUN/NNS
# features/NOUN/NNS <--dobj-- has/AUX/VBZ
# such/ADJ/JJ <--amod-- as/SCONJ/IN
# as/SCONJ/IN <--prep-- features/NOUN/NNS
# PowerPano/PROPN/NNP <--pobj-- as/SCONJ/IN
# ,/PUNCT/, <--punct-- has/AUX/VBZ
# it/PRON/PRP <--nsubj-- has/AUX/VBZ
# also/ADV/RB <--advmod-- has/AUX/VBZ
# has/AUX/VBZ <--ROOT-- has/AUX/VBZ
# great/ADJ/JJ <--amod-- hardware/NOUN/NN
# hardware/NOUN/NN <--dobj-- has/AUX/VBZ
# and/CCONJ/CC <--cc-- hardware/NOUN/NN
# a/DET/DT <--det-- screen/NOUN/NN
# really/ADV/RB <--advmod-- good/ADJ/JJ
# good/ADJ/JJ <--amod-- screen/NOUN/NN
# touch/NOUN/NN <--compound-- screen/NOUN/NN
# screen/NOUN/NN <--conj-- hardware/NOUN/NN
# ./PUNCT/. <--punct-- has/AUX/VBZ
# But/CCONJ/CC <--cc-- came/VERB/VBD
# for/ADP/IN <--prep-- came/VERB/VBD
# me/PRON/PRP <--pobj-- for/ADP/IN
# ,/PUNCT/, <--punct-- came/VERB/VBD
# it/PRON/PRP <--nsubj-- came/VERB/VBD
# came/VERB/VBD <--ROOT-- came/VERB/VBD
# down/ADP/RP <--prt-- came/VERB/VBD
# to/ADP/IN <--prep-- came/VERB/VBD
# the/DET/DT <--det-- ease/NOUN/NN
# ease/NOUN/NN <--pobj-- to/ADP/IN
# of/ADP/IN <--prep-- ease/NOUN/NN
# use/NOUN/NN <--pobj-- of/ADP/IN
# of/ADP/IN <--prep-- use/NOUN/NN
# the/DET/DT <--det-- app/NOUN/NN
# app/NOUN/NN <--pobj-- of/ADP/IN
# that/PRON/WDT <--nsubj-- made/VERB/VBD
# made/VERB/VBD <--relcl-- ease/NOUN/NN
# me/PRON/PRP <--nsubj-- keep/VERB/VB
# wanna/PROPN/NNP <--nsubj-- keep/VERB/VB
# keep/VERB/VB <--ccomp-- made/VERB/VBD
# using/VERB/VBG <--xcomp-- keep/VERB/VB
# this/DET/DT <--det-- thing/NOUN/NN
# thing/NOUN/NN <--dobj-- using/VERB/VBG
# ./PUNCT/. <--punct-- came/VERB/VBD
# 360/NUM/CD <--nummod-- footage/NOUN/NN
# footage/NOUN/NN <--ROOT-- footage/NOUN/NN
# used/VERB/VBD <--acl-- footage/NOUN/NN
# to/PART/TO <--aux-- mean/VERB/VB
# mean/VERB/VB <--xcomp-- used/VERB/VBD
# high/ADJ/JJ <--amod-- end/NOUN/NN
# -/PUNCT/HYPH <--punct-- end/NOUN/NN
# end/NOUN/NN <--compound-- equipment/NOUN/NN
# equipment/NOUN/NN <--dobj-- mean/VERB/VB
# and/CCONJ/CC <--cc-- equipment/NOUN/NN
# tons/NOUN/NNS <--conj-- equipment/NOUN/NN
# of/ADP/IN <--prep-- tons/NOUN/NNS
# headaches/NOUN/NNS <--pobj-- of/ADP/IN
# and/CCONJ/CC <--cc-- headaches/NOUN/NNS
# post/NOUN/NN <--conj-- headaches/NOUN/NNS
# ,/PUNCT/, <--punct-- used/VERB/VBD
# and/CCONJ/CC <--cc-- used/VERB/VBD
# that/DET/DT <--nsubj-- pushed/VERB/VBD
# always/ADV/RB <--advmod-- pushed/VERB/VBD
# pushed/VERB/VBD <--conj-- used/VERB/VBD
# me/PRON/PRP <--dobj-- pushed/VERB/VBD
# away/ADV/RB <--advmod-- pushed/VERB/VBD
# from/ADP/IN <--prep-- away/ADV/RB
# using/VERB/VBG <--pcomp-- from/ADP/IN
# it/PRON/PRP <--dobj-- using/VERB/VBG
# ./PUNCT/. <--punct-- footage/NOUN/NN
# But/CCONJ/CC <--cc-- 's/AUX/VBZ
# when/ADV/WRB <--advmod-- put/VERB/VBP
# you/PRON/PRP <--nsubj-- put/VERB/VBP
# put/VERB/VBP <--advcl-- 's/AUX/VBZ
# all/DET/DT <--dobj-- put/VERB/VBP
# of/ADP/IN <--prep-- all/DET/DT
# that/DET/DT <--pobj-- of/ADP/IN
# into/ADP/IN <--prep-- put/VERB/VBP
# the/DET/DT <--det-- factor/NOUN/NN
# form/NOUN/NN <--compound-- factor/NOUN/NN
# factor/NOUN/NN <--pobj-- into/ADP/IN
# of/ADP/IN <--prep-- factor/NOUN/NN
# a/DET/DT <--det-- GoPro/PROPN/NNP
# GoPro/PROPN/NNP <--pobj-- of/ADP/IN
# ,/PUNCT/, <--punct-- GoPro/PROPN/NNP
# a/DET/DT <--det-- workflow/NOUN/NN
# workflow/NOUN/NN <--appos-- GoPro/PROPN/NNP
# I/PRON/PRP <--nsubj-- using/VERB/VBG
# 've/AUX/VB <--aux-- using/VERB/VBG
# been/AUX/VBN <--aux-- using/VERB/VBG
# using/VERB/VBG <--relcl-- workflow/NOUN/NN
# for/ADP/IN <--prep-- using/VERB/VBG
# years/NOUN/NNS <--pobj-- for/ADP/IN
# ,/PUNCT/, <--punct-- 's/AUX/VBZ
# it/PRON/PRP <--nsubj-- 's/AUX/VBZ
# 's/AUX/VBZ <--ROOT-- 's/AUX/VBZ
# way/ADV/RB <--npadvmod-- approachable/ADJ/JJ
# more/ADV/RBR <--advmod-- approachable/ADJ/JJ
# approachable/ADJ/JJ <--acomp-- 's/AUX/VBZ
# ./PUNCT/. <--punct-- 's/AUX/VBZ
# Now/ADV/RB <--advmod-- is/AUX/VBZ
# ,/PUNCT/, <--punct-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# all/DET/DT <--nsubj-- is/AUX/VBZ
# of/ADP/IN <--prep-- all/DET/DT
# that/DET/DT <--pobj-- of/ADP/IN
# enough/ADJ/JJ <--acomp-- is/AUX/VBZ
# to/PART/TO <--aux-- make/VERB/VB
# make/VERB/VB <--xcomp-- enough/ADJ/JJ
# this/DET/DT <--det-- thing/NOUN/NN
# thing/NOUN/NN <--nsubj-- more/ADJ/JJR
# more/ADJ/JJR <--ccomp-- make/VERB/VB
# than/SCONJ/IN <--prep-- more/ADJ/JJR
# a/DET/DT <--det-- camera/NOUN/NN
# novelty/ADJ/JJ <--compound-- camera/NOUN/NN
# camera/NOUN/NN <--pobj-- than/SCONJ/IN
# that/PRON/WDT <--nsubj-- end/VERB/VB
# will/AUX/MD <--aux-- end/VERB/VB
# ultimately/ADV/RB <--advmod-- end/VERB/VB
# end/VERB/VB <--relcl-- camera/NOUN/NN
# up/ADP/RP <--prt-- end/VERB/VB
# in/ADP/IN <--prep-- end/VERB/VB
# my/PRON/PRP$ <--poss-- bed/NOUN/NN
# forgotten/ADJ/JJ <--amod-- bed/NOUN/NN
# type/NOUN/NN <--compound-- bed/NOUN/NN
# bed/NOUN/NN <--pobj-- in/ADP/IN
# in/ADP/IN <--prep-- end/VERB/VB
# my/PRON/PRP$ <--poss-- basement/NOUN/NN
# basement/NOUN/NN <--pobj-- in/ADP/IN
# ?/PUNCT/. <--punct-- is/AUX/VBZ
# Time/PROPN/NNP <--nsubj-- tell/VERB/VB
# will/AUX/MD <--aux-- tell/VERB/VB
# truly/ADV/RB <--advmod-- tell/VERB/VB
# tell/VERB/VB <--ROOT-- tell/VERB/VB
# ./PUNCT/. <--punct-- tell/VERB/VB
# But/CCONJ/CC <--cc-- is/AUX/VBZ
# it/PRON/PRP <--nsubj-- is/AUX/VBZ
# is/AUX/VBZ <--ROOT-- is/AUX/VBZ
# the/DET/DT <--det-- fun/NOUN/NN
# most/ADJ/JJS <--advmod-- fun/NOUN/NN
# fun/NOUN/NN <--nmod-- camera/NOUN/NN
# and/CCONJ/CC <--cc-- fun/NOUN/NN
# user/NOUN/NN <--npadvmod-- friendly/ADJ/JJ
# -/PUNCT/HYPH <--punct-- friendly/ADJ/JJ
# friendly/ADJ/JJ <--conj-- fun/NOUN/NN
# 360/NUM/CD <--nummod-- camera/NOUN/NN
# camera/NOUN/NN <--attr-- is/AUX/VBZ
# I/PRON/PRP <--nsubj-- used/VERB/VBN
# have/AUX/VBP <--aux-- used/VERB/VBN
# used/VERB/VBN <--relcl-- camera/NOUN/NN
# today/NOUN/NN <--npadvmod-- used/VERB/VBN
# ./PUNCT/. <--punct-- is/AUX/VBZ
# And/CCONJ/CC <--cc-- 'm/AUX/VBP
# I/PRON/PRP <--nsubj-- 'm/AUX/VBP
# 'm/AUX/VBP <--ROOT-- 'm/AUX/VBP
# excited/ADJ/JJ <--acomp-- 'm/AUX/VBP
# to/PART/TO <--aux-- see/VERB/VB
# see/VERB/VB <--xcomp-- excited/ADJ/JJ
# this/DET/DT <--det-- thing/NOUN/NN
# thing/NOUN/NN <--nsubj-- specced/VERB/VBN
# as/SCONJ/IN <--mark-- specced/VERB/VBN
# specced/VERB/VBN <--ccomp-- see/VERB/VB
# out/ADP/RP <--prt-- specced/VERB/VBN
# ./PUNCT/. <--punct-- 'm/AUX/VBP
# (/PUNCT/-LRB- <--punct-- coughing/VERB/VBG
# coughing/VERB/VBG <--ROOT-- coughing/VERB/VBG
# )/PUNCT/-RRB- <--punct-- coughing/VERB/VBG
# 4/NUM/CD <--nummod-- mode/NOUN/NN
# K/PROPN/NNP <--compound-- Hero/PROPN/NNP
# Hero/PROPN/NNP <--compound-- mode/NOUN/NN
# mode/NOUN/NN <--dobj-- coughing/VERB/VBG
# ?/PUNCT/. <--punct-- coughing/VERB/VBG
# Please/INTJ/UH <--ROOT-- Please/INTJ/UH
# ?/PUNCT/. <--punct-- Please/INTJ/UH
# All/ADV/RB <--advmod-- right/ADV/RB
# right/ADV/RB <--advmod-- order/VERB/VB
# ,/PUNCT/, <--punct-- order/VERB/VB
# so/ADV/RB <--advmod-- order/VERB/VB
# for/ADP/IN <--prep-- order/VERB/VB
# 499/NUM/CD <--pobj-- for/ADP/IN
# ,/PUNCT/, <--punct-- order/VERB/VB
# you/PRON/PRP <--nsubj-- order/VERB/VB
# can/AUX/MD <--aux-- order/VERB/VB
# pre/VERB/VB <--dep-- -/VERB/VB
# -/VERB/VB <--dep-- order/VERB/VB
# order/VERB/VB <--ROOT-- order/VERB/VB
# a/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--dobj-- order/VERB/VB
# today/NOUN/NN <--npadvmod-- order/VERB/VB
# ./PUNCT/. <--punct-- order/VERB/VB
# They/PRON/PRP <--nsubj-- start/VERB/VBP
# start/VERB/VBP <--ROOT-- start/VERB/VBP
# shipping/VERB/VBG <--xcomp-- start/VERB/VBP
# on/ADP/IN <--prep-- shipping/VERB/VBG
# October/PROPN/NNP <--compound-- 24th/NOUN/NN
# 24th/NOUN/NN <--pobj-- on/ADP/IN
# and/CCONJ/CC <--cc-- start/VERB/VBP
# will/AUX/MD <--aux-- be/AUX/VB
# be/AUX/VB <--conj-- start/VERB/VBP
# on/ADP/IN <--prep-- be/AUX/VB
# shelves/NOUN/NNS <--pobj-- on/ADP/IN
# October/PROPN/NNP <--compound-- 27th/NOUN/NN
# 27th/NOUN/NN <--npadvmod-- be/AUX/VB
# ./PUNCT/. <--punct-- start/VERB/VBP
# The/DET/DT <--det-- space/NOUN/NN
# 360/NUM/CD <--nummod-- space/NOUN/NN
# space/NOUN/NN <--nsubj-- getting/VERB/VBG
# is/AUX/VBZ <--aux-- getting/VERB/VBG
# getting/VERB/VBG <--ROOT-- getting/VERB/VBG
# kinda/ADV/RB <--amod-- nuts/NOUN/NNS
# nuts/NOUN/NNS <--dobj-- getting/VERB/VBG
# and/CCONJ/CC <--cc-- nuts/NOUN/NNS
# the/DET/DT <--det-- X/NOUN/NN
# One/NUM/CD <--compound-- X/NOUN/NN
# X/NOUN/NN <--nsubj-- deserves/VERB/VBZ
# versus/ADP/IN <--prep-- X/NOUN/NN
# the/DET/DT <--det-- Max/PROPN/NNP
# Max/PROPN/NNP <--pobj-- versus/ADP/IN
# deserves/VERB/VBZ <--conj-- getting/VERB/VBG
# its/PRON/PRP$ <--poss-- videos/NOUN/NNS
# whole/ADJ/JJ <--amod-- videos/NOUN/NNS
# own/ADJ/JJ <--amod-- videos/NOUN/NNS
# videos/NOUN/NNS <--dobj-- deserves/VERB/VBZ
# ,/PUNCT/, <--punct-- getting/VERB/VBG
# so/CCONJ/CC <--cc-- getting/VERB/VBG
# I/PRON/PRP <--nsubj-- guess/VERB/VBP
# guess/VERB/VBP <--conj-- getting/VERB/VBG
# I/PRON/PRP <--nsubj-- see/VERB/VB
# 'll/VERB/MD <--aux-- see/VERB/VB
# see/VERB/VB <--ccomp-- guess/VERB/VBP
# you/PRON/PRP <--nmod-- guys/NOUN/NNS
# guys/NOUN/NNS <--dobj-- see/VERB/VB
# next/ADJ/JJ <--amod-- time/NOUN/NN
# time/NOUN/NN <--npadvmod-- see/VERB/VB
# ./PUNCT/. <--punct-- guess/VERB/VBP

# %%
text = examples[2]
doc = spacy_nlp(text)
sentence_tokens = [sents.text for sents in doc.sents]

# %%
sentence_tokens
# Out:
# [' Google has been building its own Chromebooks for a while now',
#  'first there were two iterations of the Chromebook pixel and then there was 2017 pixel book all three worked great laptops with one huge flaw they cost way too much money',
#  "Google's back at it again this year with the new pixel book go and for the first time Google's not trying to make the best Chromebook ever price be damned [Music]",
#  'instead Google is trying to build a Chromebook that anyone can use and afford the pixel will go starts at six hundred and fifty dollars a full 350 less than the original pixel book',
#  "it's still a lot of money for a Chromebook",
#  "but for the first time Google's built something better than the cheap low-end Chromebooks out there that still semi affordable unfortunately in its quest to get the price down Google",
#  'also second rest a lot of what made the original pixel looks so intriguing in the first place but for a lot of people',
#  "those trade-offs will be worth it all of Google's previous Chromebooks as well as last year's ill-fated pixel slate tablet had distinctive designs and premium hardware with very few corners cut while the pixel book though is a nice device",
#  "it's a phone or pedestrian computer than anything Google has released thus far",
#  "it's a basic looking clamshell laptop with a 13.3 inch 1080p touchscreen and a black paint job unmarked except for a small Google Gee logo in the corner of the lid it also comes in very light pink with a bright coral",
#  'underside',
#  "a much more distinctive combo but the all-black has a certain understated elegance either way the go feels sturdy and well built but doesn't have any of the distinctive design elements you'll see in the original pixel book",
#  "it's thicker than that device still weighs about the same at 2.3 pounds",
#  'I definitely miss the aesthetics of the original',
#  "though particularly it's glass an aluminum lid that echoed the design of goulds pixel phones the go as a functional utilitarian design which I can appreciate",
#  'but I wish it was slightly more exciting',
#  "there is one new funky design flourish to be found the pixel book go it's ridged underside for whatever reason pictures made me think that this was a different softer material than the magnesium that makes up the rest of the goes case but it doesn't feel any different than the rest of the device google",
#  'says it design needs word just to make the laptop easier to grip or pull out of a sleeve',
#  "but I can't have had any problems handling other computers",
#  "still it's good to see Google's more playful side on this otherwise dull laptop and while the goal might be a little boring",
#  'it still feels nicer and sturdier than almost any other Chromebook on the market',
#  "the otherwise excellent Asus Chromebook flip that I reviewed earlier this year it's much heavier than the go for example",
#  "Google's surely simplified its design as a way to cut costs and as such there are some other notable changes to the go compared to its predecessor unlike the first pixel book",
#  "it's not a convertible so tablet mode",
#  "is out that also means it doesn't work with the pixel book pen stylus both the pixel book in the pixel slate at excellent displays with a taller aspect ratio and higher resolutions in the pixel book",
#  'go',
#  "and I'm a little sad to see the step back and display quality here",
#  "that's not to say the Dell has a bad screen",
#  "it's just not nearly as gorgeous to look at as those last two computers 1080p on a 13.3 inch screen",
#  'works out to 166 pixels per inch a far cry from the 235 PPI on the first pixel book and the impressive 293 PPI on the pixel sleep Google did build a go with a 4k screen but that option is only available if you get a top-of-the-line model which costs an eye-popping thirteen hundred and ninety nine dollars the good news is that the go as much slimmer bezels around the screen than the original pixel book',
#  'but I still prefer the taller and more pixel dense display on that laptop to the screen on the go fortunately',
#  "Google didn't skimp out on the keyboard",
#  'the original pixel book offered a great typing experience and the go is almost as good',
#  "I can't quite put my finger on what's different but the keys don't feel quite as soft when you're typing that set",
#  "there's plenty of travel and they're pretty quiet Google about the whole thing right here",
#  'the trackpad under their hand is just fine',
#  "it feels kind of rough under my finger and scrolling around isn't as smooth",
#  "as I'd like",
#  "it's not bad",
#  "and I've gotten used to it",
#  "but I've definitely used better touch beds",
#  'well google cut some corners in the design department the pixel book go',
#  'is still among the more powerful Chromebooks out there',
#  'the base model pairs an eighth generation Intel Core m3 processor with 8 gigabytes of RAM and 64 gigabytes of storage the one I reviewed steps up to an i5 processor in 128 gigabytes of storage that model costs $849 comparable to what defined in',
#  'the nine $99 pixel look',
#  "I wish I could have tried that m3 model because I really want to see what kind of performance Google is offering for $650 unsurprisingly Intel's Core i5 and eight gigs of ram is plenty for Chrome OS",
#  "the pixel book go handle my normal workload without any issues my routine involves a dozen or so browser tabs TweetDeck hangouts slack todoist google keep and Trello all running as Chrome apps along with the occasional Android app or to Adobe's Lightroom Netflix and YouTube music all mostly worked well although music playback had the occasional low memory hiccup which is frustrating",
#  "notably this didn't happen when using YouTube music as a browser tab",
#  "this reinforces my belief that Android apps on Chrome aren't usually worth using if there's a web-based alternative overall",
#  "I can't imagine most people need to upgrade from the $849 model I tried Google was also selling in 999 configuration that doubles the range of 16 gigabytes well that $13.99 model I mentioned includes a core i7 processor 16 gigs of ram 206 gigs of storage and a 4k display",
#  "well I'd surely enjoy that high res screen",
#  "I don't think it's a worthwhile upgrade for anyone",
#  "the pixel book though also holds up pretty well in the battery side something that wasn't always true with the original and our video playback test",
#  'the go ran for just over 13 and a half hours before shutting down',
#  "that's more than an hour longer than the 12 hour battery life google claims with mixed usage",
#  'unfortunately I never came close to 12 hours and putting the go through my normal routine but it did last more than eight hours which is a definite improvement over the first pixel book',
#  'all this said',
#  'the pixel book go is a much easier device to evaluate than either the first pixel book or the pixel',
#  'Slaten',
#  "it's a standard familiar almost boring laptop",
#  "but instead of figuring out if cromoz works on a convertible tablet or if you're willing to spend $1000 on a premium laptop",
#  'the go is just a straightforward no-frills device',
#  "it's still not particularly cheap especially if you step up to the i5 processor I tried but premium Chromebooks in the 600 to 800 dollar range",
#  'are becoming more common now and now Google has something that can compete on quality as well as price',
#  "yes you can still get a Chromebook for less money than what Google was asked for the NGO if you think a Chromebook can be your main computer and don't mind paying a little extra for a device that's thin light and well engineered the pixel book go will likely meet your needs thanks for watching and subscribe to and gadgets YouTube channel for more news and reviews"]
